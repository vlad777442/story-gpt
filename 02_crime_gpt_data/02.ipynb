# %% [markdown]
# **Building a Crime GPT LLM by Ravi Kumar Sinha**
#
# This code is based on *Build a Large Language Model (From Scratch)*, [https://github.com/rasbt/LLMs-from-scratch](https://github.com/rasbt/LLMs-from-scratch)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # 2) Trying to input the Crime Novel GPT Data

# %% [markdown]
# Packages that are being used in this notebook:
# We are going to use different libraries here. Pytorch,tiktoken and pandas are few of them

# %%
# !pip install transformers -q
# !pip install datasets -q
# Out:
# [notice] A new release of pip is available: 24.1.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.1.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from importlib.metadata import version
import pandas as pd
import transformers
from datasets import load_dataset

print("torch version:", version("torch"))
print("tiktoken version:", version("tiktoken"))
print(f"Transformers version: {transformers.__version__}")
# Out:
# torch version: 2.2.1+cu121
# tiktoken version: 0.7.0
# Transformers version: 4.42.3

# %% [markdown]
# - This notebook provides a brief overview of the data preparation and sampling procedures to get input data "ready" for an LLM
# - Understanding what the input data looks like is a great first step towards understanding how LLMs work

# %% [markdown]
# <img src="./figures/01.png" width="700px">

# %% [markdown]
# Let's Download the dataset
# Here I am going to make a mystery-crime-book GPT with Llama 3.2

# %%
data = load_dataset('AlekseyKorshuk/mystery-crime-books')

# %%
data['train']['url']
# Out:
# ['https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-adventures-of-sherlock-holmes/',
#  'https://www.bookrix.com/_ebook-bob-moats-classmate-murders/',
#  'https://www.bookrix.com/_ebook-david-burgess-the-samsara-project/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-hound-of-the-baskervilles-1/',
#  'https://www.bookrix.com/_ebook-sarah-j-maas-throne-of-glass/',
#  'https://www.bookrix.com/_ebook-edited-by-julian-hawthorne-library-of-the-world-039-s-best-mystery-and-detective-stories/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-the-house-on-timber-lane/',
#  'https://www.bookrix.com/_ebook-amardeep-kaur-randhawa-the-girl-next-door/',
#  'https://www.bookrix.com/_ebook-agatha-christie-murder-on-the-orient-express/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-return-of-sherlock-holmes/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-garwood-village/',
#  'https://www.bookrix.com/_ebook-kelly-abell-haunted-destiny/',
#  'https://www.bookrix.com/_ebook-scott-wampler-lucky-guy/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-the-case-of-the-missing-bride/',
#  'https://www.bookrix.com/_ebook-david-stacey-doss-the-coffee-shop-murder/',
#  'https://www.bookrix.com/_ebook-arthur-limbada-lost-at-sea/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-rip-tide/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-gifts-from-the-kasbah/',
#  'https://www.bookrix.com/_ebook-erin-clerity-death-before-dishonor/',
#  'https://www.bookrix.com/_ebook-alyza-in-plain-sight/',
#  'https://www.bookrix.com/_ebook-d-b-reynolds-brush-creek-charlie/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-a-study-in-scarlet/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-the-medusa-file/',
#  'https://www.bookrix.com/_ebook-bob-moats-vegas-showgirl-murders-book2/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-counter-blow/',
#  'https://www.bookrix.com/_ebook-ross-mac-duncan-the-beano-murders/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-memoirs-of-sherlock-holmes/',
#  'https://www.bookrix.com/_ebook-fyodor-dostoyevsky-crime-and-punishment/',
#  'https://www.bookrix.com/_ebook-katherine-angela-yeboah-lucid-sample-chapters/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-captain-of-the-polestar/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-ahzreal/',
#  'https://www.bookrix.com/_ebook-c-m-albrecht-the-sand-bluff-murders/',
#  'https://www.bookrix.com/_ebook-c-m-albrecht-evidence/',
#  'https://www.bookrix.com/_ebook-becca-a-the-hidden/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-blood-brook/',
#  'https://www.bookrix.com/_ebook-regi-s-riddle/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-mckenna/',
#  'https://www.bookrix.com/_ebook-kelly-abell-sealed-in-lies/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-the-borgias/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-valley-of-fear/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-the-case-of-the-barefoot-boys/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-mystery-of-cloomber/',
#  'https://www.bookrix.com/_ebook-mysterious-6-who-039-s-the-murderer/',
#  'https://www.bookrix.com/_ebook-grace-cavendish-fabiha-zaman-the-lady-grace-mysteries/',
#  'https://www.bookrix.com/_ebook-c-m-albrecht-tape/',
#  'https://www.bookrix.com/_ebook-tasha-m-the-mystery-of-tifton-georgia/',
#  'https://www.bookrix.com/_ebook-nikki-miller-death-to-all/',
#  'https://www.bookrix.com/_ebook-darwen-amos-an-unlikely-death/',
#  'https://www.bookrix.com/_ebook-daisy-graham-the-perfect-spy/',
#  'https://www.bookrix.com/_ebook-c-mari-abby/',
#  'https://www.bookrix.com/_ebook-redkite-intoxication/',
#  'https://www.bookrix.com/_ebook-elle-marie-calhoun-aaron-wilson-superspy-extrodinare/',
#  'https://www.bookrix.com/_ebook-james-mad-monk-death-comes/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-warrior-song/',
#  'https://www.bookrix.com/_ebook-jacob-walls-drop-of-water/',
#  'https://www.bookrix.com/_ebook-shelby-alexander-flashbacks/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-tales-of-terror-and-mystery/',
#  'https://www.bookrix.com/_ebook-angely-mercado-local-woman-stabbed-as-turbulent-past-comes-to-light/',
#  'https://www.bookrix.com/_ebook-benjamin-harris-the-end-of-tom-strauss/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-a-predetermined-course-of-events/',
#  'https://www.bookrix.com/_ebook-charles-dickens-three-ghost-stories/',
#  'https://www.bookrix.com/_ebook-michelle-kidd-anybody-039-s-child/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-adventure-of-the-devil-039-s-foot/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-counterpart/',
#  'https://www.bookrix.com/_ebook-monkwalk-the-other-me/',
#  'https://www.bookrix.com/_ebook-jay-wilson-the-murder-of-cherry-creek/',
#  'https://www.bookrix.com/_ebook-quincy-moore-decisions/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-sign-of-the-four/',
#  'https://www.bookrix.com/_ebook-hayle-miller-kidnapped/',
#  'https://www.bookrix.com/_ebook-rebekah-shimer-silence/',
#  'https://www.bookrix.com/_ebook-madison-williams-love-peace-and-murder/',
#  'https://www.bookrix.com/_ebook-crimson-skye-dating-a-geek/',
#  'https://www.bookrix.com/_ebook-brianna-jones-born-to-lie/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-massacres-of-the-south-1551-1815/',
#  'https://www.bookrix.com/_ebook-kyler-james-grimshaw-mysteries/',
#  'https://www.bookrix.com/_ebook-jeffrey-allen-white-a-difficult-autumn/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-basham/',
#  'https://www.bookrix.com/_ebook-marion-smith-the-adventure-of-the-posthumous-apparition/',
#  'https://www.bookrix.com/_ebook-kelemen-a-picnic-039-s-murder/',
#  'https://www.bookrix.com/_ebook-ilike-jellybabies-riddles/',
#  'https://www.bookrix.com/_ebook-nomar-knight-they-can-039-t-kill-us-all/',
#  'https://www.bookrix.com/_ebook-shruthi-viswanathan-the-toystore-murder/',
#  'https://www.bookrix.com/_ebook-scotty-hicks-the-beast/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-la-danza-morte-039/',
#  'https://www.bookrix.com/_ebook-thomas-dubbs-2012-secrets-and-the-mystery/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-the-case-of-the-bog-bodies/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-the-case-of-the-berkshire-hog/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-the-wives-of-edward-denbre/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-adventure-of-the-dying-detective/',
#  'https://www.bookrix.com/_ebook-john-kendrick-bangs-r-holmes-co/',
#  'https://www.bookrix.com/_ebook-aaron-redfern-mad-like-a-simile/',
#  'https://www.bookrix.com/_ebook-jeffrey-allen-white-my-brother-039-s-keeper/',
#  'https://www.bookrix.com/_ebook-honore-de-balzac-an-historical-mystery/',
#  'https://www.bookrix.com/_ebook-richard-masters-jack-jill/',
#  'https://www.bookrix.com/_ebook-robert-barr-jennie-baxter-journalist/',
#  'https://www.bookrix.com/_ebook-daniel-books-the-bloody-letter-secret/',
#  'https://www.bookrix.com/_ebook-confusedalarms-the-business/',
#  'https://www.bookrix.com/_ebook-letty-l-linhart-murder-at-the-trailer-park-1/',
#  'https://www.bookrix.com/_ebook-amber-rae-a-rae-of-sunshine/',
#  'https://www.bookrix.com/_ebook-hans-bernard-the-perfect-murder/',
#  'https://www.bookrix.com/_ebook-jacob-long-jacky-hazardous/',
#  'https://www.bookrix.com/_ebook-erin-clerity-dark-keys/',
#  'https://www.bookrix.com/_ebook-robert-f-clifton-mister-dingledine/',
#  'https://www.bookrix.com/_ebook-gabby-estrada-a-k-a-trixie-delight-the-night-my-daddy-murdered-me/',
#  'https://www.bookrix.com/_ebook-branique-mcknight-a-nigga/',
#  'https://www.bookrix.com/_ebook-deborah-cheeseboro-werewolves-vs-vampires/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-disappearance-of-lady-frances-carfax/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-my-friend-the-murderer/',
#  'https://www.bookrix.com/_ebook-bs-murthy-prey-on-the-prowl-a-crime-novel/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-adventure-of-wisteria-lodge/',
#  'https://www.bookrix.com/_ebook-the-general-himself-death-come-swiftly/',
#  'https://www.bookrix.com/_ebook-brooke-l-private-eye/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-doings-of-raffles-haw/',
#  'https://www.bookrix.com/_ebook-quailycat-the-six-fingered-doll/',
#  'https://www.bookrix.com/_ebook-mary-mccausland-anny-039-s-clover/',
#  'https://www.bookrix.com/_ebook-harshavardhan-c-after-death-an-ultimate-truth/',
#  'https://www.bookrix.com/_ebook-ameera-butt-what-039-s-hidden-within-me/',
#  'https://www.bookrix.com/_ebook-kaela-greenberry-my-singers/',
#  'https://www.bookrix.com/_ebook-amber-black-partner-in-crime/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-mary-stuart/',
#  'https://www.bookrix.com/_ebook-crazykoolaidwriter-search-rescue-solve/',
#  'https://www.bookrix.com/_ebook-meaghan-larson-cheer-before-fear/',
#  'https://www.bookrix.com/_ebook-charles-dickens-hunted-down/',
#  'https://www.bookrix.com/_ebook-jess-wygle-vigilante/',
#  'https://www.bookrix.com/_ebook-laurie-comeaux-the-shadow-in-the-hall/',
#  'https://www.bookrix.com/_ebook-whatup1105-books-the-mystery/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-adventure-of-the-red-circle/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-adventure-of-the-cardboard-box/',
#  'https://www.bookrix.com/_ebook-kaitlyn-garlets-fears/',
#  'https://www.bookrix.com/_ebook-just-us-friendz-blind-ambition/',
#  'https://www.bookrix.com/_ebook-robi-crusoe-it-all-started-at-four-corners/',
#  'https://www.bookrix.com/_ebook-megan-lewis-sheep-snatcher-thief-catcher-what-8217-s-the-good-in-that-old-thatcher/',
#  'https://www.bookrix.com/_ebook-m-m-k-and-aaron-kelley-within-the-forest/',
#  'https://www.bookrix.com/_ebook-sabrina-crowder-jessica/',
#  'https://www.bookrix.com/_ebook-anzy-irani-the-case-of-the-missing-scientist/',
#  'https://www.bookrix.com/_ebook-sara-hansen-who-am-i/',
#  'https://www.bookrix.com/_ebook-k-darley-dancing-on-strings/',
#  'https://www.bookrix.com/_ebook-m-jade-glock-it-takes-two-to-murder/',
#  'https://www.bookrix.com/_ebook-robi-crusoe-hope-is-a-very-mysterious-thing/',
#  'https://www.bookrix.com/_ebook-charles-dickens-the-mystery-of-edwin-drood/',
#  'https://www.bookrix.com/_ebook-chris-harris-grimshaw-amp-mortimer-the-case-book/',
#  'https://www.bookrix.com/_ebook-kimba-sue-the-killer-at-the-library/',
#  'https://www.bookrix.com/_ebook-alice-f-green-artist-meets-con/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-vaninka/',
#  'https://www.bookrix.com/_ebook-j-m-burlock-the-burning-of-books/',
#  'https://www.bookrix.com/_ebook-erin-clerity-death-before-dishonor-retribution/',
#  'https://www.bookrix.com/_ebook-jermey-michael-henley-island/',
#  'https://www.bookrix.com/_ebook-by-daniella-willey-the-black-butterfly/',
#  'https://www.bookrix.com/_ebook-montana-schmidt-molly-039-s-mystery/',
#  'https://www.bookrix.com/_ebook-ron-feasel-moral-dilemma/',
#  'https://www.bookrix.com/_ebook-angel-of-death-the-forgotten-book/',
#  'https://www.bookrix.com/_ebook-seren-do-you-believe-in-ghosts/',
#  'https://www.bookrix.com/_ebook-aaron-wise-untrace-able-chapter-1/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-his-last-bow/',
#  'https://www.bookrix.com/_ebook-natalie-wood-saving-alex-storm/',
#  'https://www.bookrix.com/_ebook-katie-r-jamison-the-mystery-of-haverlin-manor-in-progress/',
#  'https://www.bookrix.com/_ebook-mell-corcoran-shadows-of-deceit/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-joan-of-naples/',
#  'https://www.bookrix.com/_ebook-sola-luna-the-case-of-the-quot-dear-diary-killer-quot/',
#  'https://www.bookrix.com/_ebook-legacy-jackson-akatsuki-no-kuruma/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-urbain-grandier/',
#  'https://www.bookrix.com/_ebook-michelle-kidd-timeless-moments/',
#  'https://www.bookrix.com/_ebook-raymond-beresford-hamilton-solomon-039-s-ring/',
#  'https://www.bookrix.com/_ebook-redhead16-mlm-the-cheating-thief/',
#  'https://www.bookrix.com/_ebook-dreoilin-seven-sins/',
#  'https://www.bookrix.com/_ebook-kareca-shadowless/',
#  'https://www.bookrix.com/_ebook-angel-ortiz-the-disappearance/',
#  'https://www.bookrix.com/_ebook-by-k-f-dawson-criminal-love/',
#  'https://www.bookrix.com/_ebook-megan-stringfellow-27-kills/',
#  'https://www.bookrix.com/_ebook-dan-hardy-eye-of-the-destroyer/',
#  'https://www.bookrix.com/_ebook-jk-irving-mystic-flower/',
#  'https://www.bookrix.com/_ebook-tennistar-unforgettable-images/',
#  'https://www.bookrix.com/_ebook-danielle-white-hidden/',
#  'https://www.bookrix.com/_ebook-soumya-sarkar-the-film/',
#  'https://www.bookrix.com/_ebook-kyler-james-grimshaw-mysteries-2/',
#  'https://www.bookrix.com/_ebook-sir-arthur-conan-doyle-the-adventure-of-bruce-partington-plans/',
#  'https://www.bookrix.com/_ebook-michael-pennington-zhena-sample-chapters/',
#  'https://www.bookrix.com/_ebook-redhead16-mlm-mysterious/',
#  'https://www.bookrix.com/_ebook-radia-al-rashid-eyes-like-ice/',
#  'https://www.bookrix.com/_ebook-terrex-corbin-who-is-mr-code/',
#  'https://www.bookrix.com/_ebook-xxkyliexx123-who-am-i/',
#  'https://www.bookrix.com/_ebook-legacy-jackson-akatsuki-no-kuruma-1/',
#  'https://www.bookrix.com/_ebook-zema-zuruki-the-sad-end/',
#  'https://www.bookrix.com/_ebook-ren-willi-the-dissappearance-fo-madeline-shultz/',
#  'https://www.bookrix.com/_ebook-valerie-ziegler-life-of-a-reformed-wild-child/',
#  'https://www.bookrix.com/_ebook-j-n-taylor-echo/',
#  'https://www.bookrix.com/_ebook-jahari-webb-secrets-1/',
#  'https://www.bookrix.com/_ebook-kenzie-stone-appalachian-arsenic/',
#  'https://www.bookrix.com/_ebook-c-kelemen-the-winter-mill-murder/',
#  'https://www.bookrix.com/_ebook-sidney-c-wilson-jason-hewitt-mysteries/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-la-constantin/',
#  'https://www.bookrix.com/_ebook-confusedalarms-scenes-from-a-memory/',
#  'https://www.bookrix.com/_ebook-anastasia-timmons-the-girl-who-disappeared/',
#  'https://www.bookrix.com/_ebook-paula-louise-shene-the-face-of-evil/',
#  'https://www.bookrix.com/_ebook-kirsten-lott-his-golden-tears/',
#  'https://www.bookrix.com/_ebook-m-j-garrett-first-chance-last-chance/',
#  'https://www.bookrix.com/_ebook-callele-lyvance-fetiche/',
#  'https://www.bookrix.com/_ebook-tyler-lace-thief-in-the-shadows/',
#  'https://www.bookrix.com/_ebook-lharissa-charles-sad-mother/',
#  'https://www.bookrix.com/_ebook-rachelle-reese-the-thaw/',
#  'https://www.bookrix.com/_ebook-mackenzie-herrst-every-hundred-years/',
#  'https://www.bookrix.com/_ebook-ross-mac-duncan-the-brandenburg-xx-file/',
#  'https://www.bookrix.com/_ebook-faith-harper-bitter-affection/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-the-countess-of-saint-geran/',
#  'https://www.bookrix.com/_ebook-abby-moran-geraldo/',
#  'https://www.bookrix.com/_ebook-scathach-danu-sweet-caroline/',
#  'https://www.bookrix.com/_ebook-bookworm7979-cadena-my-killer/',
#  'https://www.bookrix.com/_ebook-sydney-st-fleur-ashes-and-diamonds/',
#  'https://www.bookrix.com/_ebook-the-general-himself-death-from-the-past/',
#  'https://www.bookrix.com/_ebook-brady-h-the-ransacked-building/',
#  'https://www.bookrix.com/_ebook-alexia-marshall-truth/',
#  'https://www.bookrix.com/_ebook-by-morgan-burn/',
#  'https://www.bookrix.com/_ebook-sin-c-beautiful-killers/',
#  'https://www.bookrix.com/_ebook-matteo-castro-the-great-revange/',
#  'https://www.bookrix.com/_ebook-hannah-butler-the-key-inside-the-wooden-chest/',
#  'https://www.bookrix.com/_ebook-amy-lockhart-shhh-the-name-of-this-book-is-classified/',
#  'https://www.bookrix.com/_ebook-elle-marie-calhoun-the-mystery-diaries/',
#  'https://www.bookrix.com/_ebook-odessa-mcniel-clarissa-odele-and-the-case-of-the-slain-newlyweds/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-karl-ludwig-sand/',
#  'https://www.bookrix.com/_ebook-lee-mandel-monopoly/',
#  'https://www.bookrix.com/_ebook-melissa-pollard-taking-revenge/',
#  'https://www.bookrix.com/_ebook-a-m-layon-the-bullies-revenge/',
#  'https://www.bookrix.com/_ebook-c-kelemen-the-lively-glow-of-death/',
#  'https://www.bookrix.com/_ebook-steve-bederman-the-ceo/',
#  'https://www.bookrix.com/_ebook-rebecca-guanabara-the-observer/',
#  'https://www.bookrix.com/_ebook-florence-hazel-call-1800-234-dead/',
#  'https://www.bookrix.com/_ebook-letty-l-linhart-murder-at-the-trailer-park/',
#  'https://www.bookrix.com/_ebook-sarah-walker-n-a/',
#  'https://www.bookrix.com/_ebook-kattie-huang-i-039-m-here/',
#  'https://www.bookrix.com/_ebook-crimson-rose-children-surrender/',
#  'https://www.bookrix.com/_ebook-natalie-m-wood-the-other-side-of-me/',
#  'https://www.bookrix.com/_ebook-h-l-w-handle-bars/',
#  'https://www.bookrix.com/_ebook-c-m-albrecht-the-albemarle-affair/',
#  'https://www.bookrix.com/_ebook-bronwyn-schulzeck-the-suspect/',
#  'https://www.bookrix.com/_ebook-ej-patterson-saving-maggie/',
#  'https://www.bookrix.com/_ebook-amaris-the-mystery-girl/',
#  'https://www.bookrix.com/_ebook-jordan-link-an-inspector-039-s-testimonial/',
#  'https://www.bookrix.com/_ebook-j-d-mincey-inside-my-mind/',
#  'https://www.bookrix.com/_ebook-kimba-sue-this-cannot-be-happening-again/',
#  'https://www.bookrix.com/_ebook-hunter-lynne-truth-in-darkness/',
#  'https://www.bookrix.com/_ebook-abbey-voss-taken-advantage/',
#  'https://www.bookrix.com/_ebook-elvira-frankenheim-the-evil-within/',
#  'https://www.bookrix.com/_ebook-danielle-nimmo-clockwork-changes/',
#  'https://www.bookrix.com/_ebook-elle-marie-calhoun-an-awakening-memory/',
#  'https://www.bookrix.com/_ebook-bronte-shepherd-time/',
#  'https://www.bookrix.com/_ebook-jonelle-patrick-fallen-angel-an-only-in-tokyo-mystery/',
#  'https://www.bookrix.com/_ebook-zheba-deception/',
#  'https://www.bookrix.com/_ebook-shady-larry-civil-being/',
#  'https://www.bookrix.com/_ebook-austin-c-drake-dream-of-the-dead/',
#  'https://www.bookrix.com/_ebook-lillian-hudson-broken-1/',
#  'https://www.bookrix.com/_ebook-k-m-montoya-who-am-i-really/',
#  'https://www.bookrix.com/_ebook-sherlet8-robin/',
#  'https://www.bookrix.com/_ebook-rue-wayles-hightail/',
#  'https://www.bookrix.com/_ebook-the-general-himself-the-face-keeper/',
#  'https://www.bookrix.com/_ebook-c-kelemen-the-birth-of-death/',
#  'https://www.bookrix.com/_ebook-bethany-r-porter-billowing-in-the-distance/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-murat/',
#  'https://www.bookrix.com/_ebook-briahna-williams-gone-in-the-wind/',
#  'https://www.bookrix.com/_ebook-yagnesh-chokasi-god-is-watching-everything/',
#  'https://www.bookrix.com/_ebook-g-j-prager-039-the-lesson-plan-039/',
#  'https://www.bookrix.com/_ebook-charles-morehouse-cannibal-assassions/',
#  'https://www.bookrix.com/_ebook-brewcris-tears-of-the-forgotten/',
#  'https://www.bookrix.com/_ebook-christopher-cabreja-helga/',
#  'https://www.bookrix.com/_ebook-rina-past-life-misian/',
#  'https://www.bookrix.com/_ebook-wayne-elder-the-mysterious-phone-caller/',
#  'https://www.bookrix.com/_ebook-kevin-jenkins-time-bomb/',
#  'https://www.bookrix.com/_ebook-cameron-percy-jeeves-the-old-house/',
#  'https://www.bookrix.com/_ebook-wintersk18-the-diary-the-twins-on-the-other-vally/',
#  'https://www.bookrix.com/_ebook-isaiahpullian-the-vampire/',
#  'https://www.bookrix.com/_ebook-melinda-dawn-mardars-satifaction-guaranteed/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-derues/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-nisida/',
#  'https://www.bookrix.com/_ebook-nathan-knox-unknown-stranger/',
#  'https://www.bookrix.com/_ebook-michael-ridgley-the-riddler-in-the-lost-phone/',
#  'https://www.bookrix.com/_ebook-sailorsenshi-a-k-a-ss-the-mystery-at-dorson-all-boys-academy/',
#  'https://www.bookrix.com/_ebook-ranz-ulanday-red-ops/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-marquise-de-ganges/',
#  'https://www.bookrix.com/_ebook-enzo-a-almario-it-039-s-not-me/',
#  'https://www.bookrix.com/_ebook-rina-past-life/',
#  'https://www.bookrix.com/_ebook-darkpoet83-ms-justice/',
#  'https://www.bookrix.com/_ebook-p-j-lawton-lethal-knowledge-excerpt/',
#  'https://www.bookrix.com/_ebook-isabelle-silvermist-changed/',
#  'https://www.bookrix.com/_ebook-bethlee-out-of-the-darkness/',
#  'https://www.bookrix.com/_ebook-kelsey-peters-bloody-love/',
#  'https://www.bookrix.com/_ebook-blue-sutcliffe-sleepless-nights/',
#  'https://www.bookrix.com/_ebook-suzanne-larosa-herlihy-diamonds-are-a-girl-039-s-best-friend-ebook/',
#  'https://www.bookrix.com/_ebook-marisa-redhead16-beg/',
#  'https://www.bookrix.com/_ebook-shaelyn-ray-fetching-kendra/',
#  'https://www.bookrix.com/_ebook-c-j-the-fugitive-files/',
#  'https://www.bookrix.com/_ebook-brian-hesse-the-m1-theory/',
#  'https://www.bookrix.com/_ebook-marisa-redhead16-rebecca/',
#  'https://www.bookrix.com/_ebook-mell-corcoran-shadows-of-doubt/',
#  'https://www.bookrix.com/_ebook-c-keelemen-the-fall-from-darkness/',
#  'https://www.bookrix.com/_ebook-redhead16-marisa-to-love-a-pretty-girl/',
#  'https://www.bookrix.com/_ebook-madison-johnson-the-begining/',
#  'https://www.bookrix.com/_ebook-rebecca-anderson-me-sometimes/',
#  'https://www.bookrix.com/_ebook-ophelia-miracle-is-life-worth-living/',
#  'https://www.bookrix.com/_ebook-blackrock-hearts-starring-black-day-light/',
#  'https://www.bookrix.com/_ebook-nick-venom-accomplice/',
#  'https://www.bookrix.com/_ebook-ayrin-southworth-catch-me-if-you-can/',
#  'https://www.bookrix.com/_ebook-ellen-jackson-killer-on-the-run/',
#  'https://www.bookrix.com/_ebook-isaiah-turner-the-playground/',
#  'https://www.bookrix.com/_ebook-evelyn-j-steward-trial-of-terror/',
#  'https://www.bookrix.com/_ebook-jack-wilson-on-the-edge-part-1/',
#  'https://www.bookrix.com/_ebook-shadowknight22-travels/',
#  'https://www.bookrix.com/_ebook-b-mckenzie-misfits/',
#  'https://www.bookrix.com/_ebook-by-cam-m-the-mysteries-of-the-secret-agent/',
#  'https://www.bookrix.com/_ebook-lubos-borik-human-source-code/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-martin-guerre/',
#  'https://www.bookrix.com/_ebook-brandonsgirl9951-aka-shannon-why-does-that-crow-follow-me/',
#  'https://www.bookrix.com/_ebook-alexandria-r-deckelman-eviscerate/',
#  'https://www.bookrix.com/_ebook-akipana-mindy-fate-sleuth/',
#  'https://www.bookrix.com/_ebook-jacob-hitchens-im-a-wizard/',
#  'https://www.bookrix.com/_ebook-lillian-m-valdez-dusk/',
#  'https://www.bookrix.com/_ebook-meara-blue-conspiracy-theorys/',
#  'https://www.bookrix.com/_ebook-debbie-adam-listen-to-the-water/',
#  'https://www.bookrix.com/_ebook-morgana-raffa-psychopath/',
#  'https://www.bookrix.com/_ebook-tara-krueger-halloween-story-pt-1/',
#  'https://www.bookrix.com/_ebook-wesley-drew-invader/',
#  'https://www.bookrix.com/_ebook-karen-revealed/',
#  'https://www.bookrix.com/_ebook-lyric-river-dee/',
#  'https://www.bookrix.com/_ebook-writer-juliet-the-unknown/',
#  'https://www.bookrix.com/_ebook-radia-al-rashid-frozen-in-time/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-cenci/',
#  'https://www.bookrix.com/_ebook-martina-rocha-changes/',
#  'https://www.bookrix.com/_ebook-mahmood-ul-hassan-the-letters/',
#  'https://www.bookrix.com/_ebook-rachel-davis-shard/',
#  'https://www.bookrix.com/_ebook-glary-woods-blood-thirsty-two-faced-medical-examiner-1/',
#  'https://www.bookrix.com/_ebook-cookiebaby-baby-framed-flower/',
#  'https://www.bookrix.com/_ebook-sarah-cornett-posioned/',
#  'https://www.bookrix.com/_ebook-jonelle-patrick-nightshade-an-only-in-tokyo-mystery/',
#  'https://www.bookrix.com/_ebook-me-tommorow-never-comes/',
#  'https://www.bookrix.com/_ebook-misty-salvesten-drownded-love/',
#  'https://www.bookrix.com/_ebook-alexandre-dumas-pere-marquise-brinvillier/',
#  'https://www.bookrix.com/_ebook-saeed-sabbagh-the-hit/',
#  'https://www.bookrix.com/_ebook-marisa-redhead16-vengeance/',
#  'https://www.bookrix.com/_ebook-marisa-redhead16-why-she-killed-her/',
#  'https://www.bookrix.com/_ebook-meghnaa-sonkar-coveted-pearl/',
#  'https://www.bookrix.com/_ebook-anonymous-cow-colors/',
#  'https://www.bookrix.com/_ebook-brandonsgirl9951-the-guy-that-apeared-in-my-room/',
#  'https://www.bookrix.com/_ebook-sreekanth-thattikota-bit-scepticism/',
#  'https://www.bookrix.com/_ebook-great-a-footprint-made-of-code/',
#  'https://www.bookrix.com/_ebook-flora-123-the-unexpected-journey/',
#  'https://www.bookrix.com/_ebook-jennifer-gisselbrecht-hyena-rise-of-the-apex-squad-2-chapter-five/',
#  'https://www.bookrix.com/_ebook-john-jones-cuckoo-in-the-nests/',
#  'https://www.bookrix.com/_ebook-john-jones-game-over/',
#  'https://www.bookrix.com/_ebook-jb-clemmens-the-numbered-cups-mystery/',
#  'https://www.bookrix.com/_ebook-john-jones-the-sunseeker/',
#  'https://www.bookrix.com/_ebook-jennifer-gisselbrecht-hyena-rise-of-the-apex-squad-2-chapter-six/',
#  'https://www.bookrix.com/_ebook-gaby-hamacher-mr-winterbottom-und-die-seele-der-nacht-1/',
#  'https://www.bookrix.com/_ebook-john-jones-tuned-in/',
#  'https://www.bookrix.com/_ebook-khb2d349d4c9cf5_1607062368.0187220573/',
#  'https://www.bookrix.com/_ebook-andrew-wilsey-the-mystery-of-the-cabin/',
#  'https://www.bookrix.com/_ebook-jalal-nono-the-king-south-east/',
#  'https://www.bookrix.com/_ebook-ellen-g-white-apocalypse/',
#  'https://www.bookrix.com/_ebook-i-nard-transitions-in-red/',
#  'https://www.bookrix.com/_ebook-ellen-g-white-armageddon/',
#  'https://www.bookrix.com/_ebook-khb2d349d4c9cf5_1607059451.4713439941/',
#  'https://www.bookrix.com/_ebook-guillaume-mwamba-the-unbendable-mvuela/']

# %%
with open('Nov_22_output_sherlock_holmes_first_book.txt', 'w') as f:
    for entry in data['train']['text'][0]:
        #text = entry['text']  # Adjust this key based on the dataset
        f.write(entry)

# %%
pwd
# Out:
# '/teamspace/studios/this_studio'

# %%
data = load_dataset('AlekseyKorshuk/mystery-crime-books')
one_book = data['train']['text'][0]
print(one_book[:1000])
# Out:
# Sir Arthur Conan Doyle The Adventures of Sherlock Holmes
#
#
#
#
#  I. A Scandal in Bohemia
#  II. The Red-headed League
#   III. A Case of Identity
#    IV. The Boscombe Valley Mystery
#    V. The Five Orange Pips
#    VI. The Man with the Twisted Lip
#    VII. The Adventure of the Blue Carbuncle
#    VIII. The Adventure of the Speckled Band
#    IX. The Adventure of the Engineer's Thumb
#   X. The Adventure of the Noble Bachelor
#    XI. The Adventure of the Beryl Coronet
#    XII. The Adventure of the Copper Beeches
#
# ADVENTURE I.   A SCANDAL IN BOHEMIA
#
# To Sherlock Holmes she is always THE woman. I have seldom heard him mention her under any other name. In his eyes she eclipses and predominates the whole of her sex. It was not that he felt any emotion akin to love for Irene Adler. All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind. He was, I take it, the most perfect reasoning and observing machine that the world has seen, but as a

# %% [markdown]
# - The goal is to tokenize and embed this text for an LLM
# - Let's develop a simple tokenizer based on some simple sample text that we can then later apply to the text above

# %%
# Save the text to a .txt file
with open('The_adventure_of_sherlock_holmes.txt', 'w', encoding='utf-8') as file:
    file.write(one_book)

# %% [markdown]
# - In this section, we tokenize text, which means breaking text into smaller units, such as individual words and punctuation characters

# %% [markdown]
# <img src="figures/02.png" width="600px">

# %% [markdown]
# - Load raw text we want to work with
# - [The Verdict by Edith Wharton](https://en.wikisource.org/wiki/The_Verdict) is a public domain short story

# %%
# !ls
# Out:
# LLM-workshop-2024			      crime_gpt		  test.json
# Nov_22_output_sherlock_holmes_first_book.txt  gpt2		  train.json
# The_adventure_of_sherlock_holmes.txt	      loss-plot.pdf
# checkpoints				      sherlock_model.pth

# %%
one_book
# Out:
# 'Sir Arthur Conan Doyle The Adventures of Sherlock Holmes \n \n \n   \n   \n I. A Scandal in Bohemia \n II. The Red-headed League \n  III. A Case of Identity \n   IV. The Boscombe Valley Mystery \n   V. The Five Orange Pips \n   VI. The Man with the Twisted Lip \n   VII. The Adventure of the Blue Carbuncle  \n   VIII. The Adventure of the Speckled Band \n   IX. The Adventure of the Engineer\'s Thumb \n  X. The Adventure of the Noble Bachelor \n   XI. The Adventure of the Beryl Coronet \n   XII. The Adventure of the Copper Beeches \n \nADVENTURE I.   A SCANDAL IN BOHEMIA \n \nTo Sherlock Holmes she is always THE woman. I have seldom heard him mention her under any other name. In his eyes she eclipses and predominates the whole of her sex. It was not that he felt any emotion akin to love for Irene Adler. All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind. He was, I take it, the most perfect reasoning and observing machine that the world has seen, but as a lover he would have placed himself in a false position. He never spoke of the softer passions, save with a gibe and a sneer. They were admirable things for the observer--excellent for drawing the veil from men\'s motives and actions. But for the trained reasoner to admit such intrusions into his own delicate and finely adjusted temperament was to introduce a distracting factor which might throw a doubt upon all his mental results. Grit in a sensitive instrument, or a crack in one of his own high-power lenses, would not be more disturbing than a strong emotion in a nature such as his. And yet there was but one woman to him, and that woman was the late Irene Adler, of dubious and questionable memory. \nI had seen little of Holmes lately. My marriage had drifted us away from each other. My own complete happiness, and the home-centred interests which rise up around the man who first finds himself master of his own establishment, were sufficient to absorb all my attention, while Holmes, who loathed every form of society with his whole Bohemian soul, remained in our lodgings in Baker Street, buried among his old books, and alternating from week to week between cocaine and ambition, the drowsiness of the drug, and the fierce energy of his own keen nature. He was still, as ever, deeply attracted by the study of crime, and occupied his immense faculties and extraordinary powers of observation in following out those clues, and clearing up those mysteries which had been abandoned as hopeless by the official police. From time to time I heard some vague account of his doings: of his summons to Odessa in the case of the Trepoff murder, of his clearing up of the singular tragedy of the Atkinson brothers at Trincomalee, and finally of the mission which he had accomplished so delicately and successfully for the reigning family of Holland. Beyond these signs of his activity, however, which I merely shared with all the readers of the daily press, I knew little of my former friend and companion. \nOne night--it was on the twentieth of March, 1888--I was returning from a journey to a patient (for I had now returned to civil practice), when my way led me through Baker Street. As I passed the well-remembered door, which must always be associated in my mind with my wooing, and with the dark incidents of the Study in Scarlet, I was seized with a keen desire to see Holmes again, and to know how he was employing his extraordinary powers. His rooms were brilliantly lit, and, even as I looked up, I saw his tall, spare figure pass twice in a dark silhouette against the blind. He was pacing the room swiftly, eagerly, with his head sunk upon his chest and his hands clasped behind him. To me, who knew his every mood and habit, his attitude and manner told their own story. He was at work again. He had risen out of his drug-created dreams and was hot upon the scent of some new problem. I rang the bell and was shown up to the chamber which had formerly been in ...

# %%
print("Total number of character:", len(one_book))
print(one_book[:99])
# Out:
# Total number of character: 562489
# Sir Arthur Conan Doyle The Adventures of Sherlock Holmes
#
#
#
#
#  I. A Scandal in Bohemia
#  II

# %% [markdown]
# <img src="figures/03.png" width="600px">

# %% [markdown]
# - The following regular expression will split on whitespaces and punctuation

# %%
import re

preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', one_book)
#preprocessed = [item for item in preprocessed if item]
print(preprocessed[:38])
# Out:
# ['Sir', ' ', 'Arthur', ' ', 'Conan', ' ', 'Doyle', ' ', 'The', ' ', 'Adventures', ' ', 'of', ' ', 'Sherlock', ' ', 'Holmes', ' ', '', '\n', '', ' ', '', '\n', '', ' ', '', '\n', '', ' ', '', ' ', '', ' ', '', '\n', '', ' ']

# %%
preprocessed
# Out:
# ['Sir',
#  ' ',
#  'Arthur',
#  ' ',
#  'Conan',
#  ' ',
#  'Doyle',
#  ' ',
#  'The',
#  ' ',
#  'Adventures',
#  ' ',
#  'of',
#  ' ',
#  'Sherlock',
#  ' ',
#  'Holmes',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  'I',
#  '.',
#  '',
#  ' ',
#  'A',
#  ' ',
#  'Scandal',
#  ' ',
#  'in',
#  ' ',
#  'Bohemia',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  'II',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Red-headed',
#  ' ',
#  'League',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  'III',
#  '.',
#  '',
#  ' ',
#  'A',
#  ' ',
#  'Case',
#  ' ',
#  'of',
#  ' ',
#  'Identity',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'IV',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Boscombe',
#  ' ',
#  'Valley',
#  ' ',
#  'Mystery',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'V',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Five',
#  ' ',
#  'Orange',
#  ' ',
#  'Pips',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'VI',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Man',
#  ' ',
#  'with',
#  ' ',
#  'the',
#  ' ',
#  'Twisted',
#  ' ',
#  'Lip',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'VII',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Adventure',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'Blue',
#  ' ',
#  'Carbuncle',
#  ' ',
#  '',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'VIII',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Adventure',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'Speckled',
#  ' ',
#  'Band',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'IX',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Adventure',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'Engineer',
#  "'",
#  's',
#  ' ',
#  'Thumb',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  'X',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Adventure',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'Noble',
#  ' ',
#  'Bachelor',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'XI',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Adventure',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'Beryl',
#  ' ',
#  'Coronet',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'XII',
#  '.',
#  '',
#  ' ',
#  'The',
#  ' ',
#  'Adventure',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'Copper',
#  ' ',
#  'Beeches',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  '\n',
#  'ADVENTURE',
#  ' ',
#  'I',
#  '.',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  'A',
#  ' ',
#  'SCANDAL',
#  ' ',
#  'IN',
#  ' ',
#  'BOHEMIA',
#  ' ',
#  '',
#  '\n',
#  '',
#  ' ',
#  '',
#  '\n',
#  'To',
#  ' ',
#  'Sherlock',
#  ' ',
#  'Holmes',
#  ' ',
#  'she',
#  ' ',
#  'is',
#  ' ',
#  'always',
#  ' ',
#  'THE',
#  ' ',
#  'woman',
#  '.',
#  '',
#  ' ',
#  'I',
#  ' ',
#  'have',
#  ' ',
#  'seldom',
#  ' ',
#  'heard',
#  ' ',
#  'him',
#  ' ',
#  'mention',
#  ' ',
#  'her',
#  ' ',
#  'under',
#  ' ',
#  'any',
#  ' ',
#  'other',
#  ' ',
#  'name',
#  '.',
#  '',
#  ' ',
#  'In',
#  ' ',
#  'his',
#  ' ',
#  'eyes',
#  ' ',
#  'she',
#  ' ',
#  'eclipses',
#  ' ',
#  'and',
#  ' ',
#  'predominates',
#  ' ',
#  'the',
#  ' ',
#  'whole',
#  ' ',
#  'of',
#  ' ',
#  'her',
#  ' ',
#  'sex',
#  '.',
#  '',
#  ' ',
#  'It',
#  ' ',
#  'was',
#  ' ',
#  'not',
#  ' ',
#  'that',
#  ' ',
#  'he',
#  ' ',
#  'felt',
#  ' ',
#  'any',
#  ' ',
#  'emotion',
#  ' ',
#  'akin',
#  ' ',
#  'to',
#  ' ',
#  'love',
#  ' ',
#  'for',
#  ' ',
#  'Irene',
#  ' ',
#  'Adler',
#  '.',
#  '',
#  ' ',
#  'All',
#  ' ',
#  'emotions',
#  ',',
#  '',
#  ' ',
#  'and',
#  ' ',
#  'that',
#  ' ',
#  'one',
#  ' ',
#  'particularly',
#  ',',
#  '',
#  ' ',
#  'were',
#  ' ',
#  'abhorrent',
#  ' ',
#  'to',
#  ' ',
#  'his',
#  ' ',
#  'cold',
#  ',',
#  '',
#  ' ',
#  'precise',
#  ' ',
#  'but',
#  ' ',
#  'admirably',
#  ' ',
#  'balanced',
#  ' ',
#  'mind',
#  '.',
#  '',
#  ' ',
#  'He',
#  ' ',
#  'was',
#  ',',
#  '',
#  ' ',
#  'I',
#  ' ',
#  'take',
#  ' ',
#  'it',
#  ',',
#  '',
#  ' ',
#  'the',
#  ' ',
#  'most',
#  ' ',
#  'perfect',
#  ' ',
#  'reasoning',
#  ' ',
#  'and',
#  ' ',
#  'observing',
#  ' ',
#  'machine',
#  ' ',
#  'that',
#  ' ',
#  'the',
#  ' ',
#  'world',
#  ' ',
#  'has',
#  ' ',
#  'seen',
#  ',',
#  '',
#  ' ',
#  'but',
#  ' ',
#  'as',
#  ' ',
#  'a',
#  ' ',
#  'lover',
#  ' ',
#  'he',
#  ' ',
#  'would',
#  ' ',
#  'have',
#  ' ',
#  'placed',
#  ' ',
#  'himself',
#  ' ',
#  'in',
#  ' ',
#  'a',
#  ' ',
#  'false',
#  ' ',
#  'position',
#  '.',
#  '',
#  ' ',
#  'He',
#  ' ',
#  'never',
#  ' ',
#  'spoke',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'softer',
#  ' ',
#  'passions',
#  ',',
#  '',
#  ' ',
#  'save',
#  ' ',
#  'with',
#  ' ',
#  'a',
#  ' ',
#  'gibe',
#  ' ',
#  'and',
#  ' ',
#  'a',
#  ' ',
#  'sneer',
#  '.',
#  '',
#  ' ',
#  'They',
#  ' ',
#  'were',
#  ' ',
#  'admirable',
#  ' ',
#  'things',
#  ' ',
#  'for',
#  ' ',
#  'the',
#  ' ',
#  'observer',
#  '--',
#  'excellent',
#  ' ',
#  'for',
#  ' ',
#  'drawing',
#  ' ',
#  'the',
#  ' ',
#  'veil',
#  ' ',
#  'from',
#  ' ',
#  'men',
#  "'",
#  's',
#  ' ',
#  'motives',
#  ' ',
#  'and',
#  ' ',
#  'actions',
#  '.',
#  '',
#  ' ',
#  'But',
#  ' ',
#  'for',
#  ' ',
#  'the',
#  ' ',
#  'trained',
#  ' ',
#  'reasoner',
#  ' ',
#  'to',
#  ' ',
#  'admit',
#  ' ',
#  'such',
#  ' ',
#  'intrusions',
#  ' ',
#  'into',
#  ' ',
#  'his',
#  ' ',
#  'own',
#  ' ',
#  'delicate',
#  ' ',
#  'and',
#  ' ',
#  'finely',
#  ' ',
#  'adjusted',
#  ' ',
#  'temperament',
#  ' ',
#  'was',
#  ' ',
#  'to',
#  ' ',
#  'introduce',
#  ' ',
#  'a',
#  ' ',
#  'distracting',
#  ' ',
#  'factor',
#  ' ',
#  'which',
#  ' ',
#  'might',
#  ' ',
#  'throw',
#  ' ',
#  'a',
#  ' ',
#  'doubt',
#  ' ',
#  'upon',
#  ' ',
#  'all',
#  ' ',
#  'his',
#  ' ',
#  'mental',
#  ' ',
#  'results',
#  '.',
#  '',
#  ' ',
#  'Grit',
#  ' ',
#  'in',
#  ' ',
#  'a',
#  ' ',
#  'sensitive',
#  ' ',
#  'instrument',
#  ',',
#  '',
#  ' ',
#  'or',
#  ' ',
#  'a',
#  ' ',
#  'crack',
#  ' ',
#  'in',
#  ' ',
#  'one',
#  ' ',
#  'of',
#  ' ',
#  'his',
#  ' ',
#  'own',
#  ' ',
#  'high-power',
#  ' ',
#  'lenses',
#  ',',
#  '',
#  ' ',
#  'would',
#  ' ',
#  'not',
#  ' ',
#  'be',
#  ' ',
#  'more',
#  ' ',
#  'disturbing',
#  ' ',
#  'than',
#  ' ',
#  'a',
#  ' ',
#  'strong',
#  ' ',
#  'emotion',
#  ' ',
#  'in',
#  ' ',
#  'a',
#  ' ',
#  'nature',
#  ' ',
#  'such',
#  ' ',
#  'as',
#  ' ',
#  'his',
#  '.',
#  '',
#  ' ',
#  'And',
#  ' ',
#  'yet',
#  ' ',
#  'there',
#  ' ',
#  'was',
#  ' ',
#  'but',
#  ' ',
#  'one',
#  ' ',
#  'woman',
#  ' ',
#  'to',
#  ' ',
#  'him',
#  ',',
#  '',
#  ' ',
#  'and',
#  ' ',
#  'that',
#  ' ',
#  'woman',
#  ' ',
#  'was',
#  ' ',
#  'the',
#  ' ',
#  'late',
#  ' ',
#  'Irene',
#  ' ',
#  'Adler',
#  ',',
#  '',
#  ' ',
#  'of',
#  ' ',
#  'dubious',
#  ' ',
#  'and',
#  ' ',
#  'questionable',
#  ' ',
#  'memory',
#  '.',
#  '',
#  ' ',
#  '',
#  '\n',
#  'I',
#  ' ',
#  'had',
#  ' ',
#  'seen',
#  ' ',
#  'little',
#  ' ',
#  'of',
#  ' ',
#  'Holmes',
#  ' ',
#  'lately',
#  '.',
#  '',
#  ' ',
#  'My',
#  ' ',
#  'marriage',
#  ' ',
#  'had',
#  ' ',
#  'drifted',
#  ' ',
#  'us',
#  ' ',
#  'away',
#  ' ',
#  'from',
#  ' ',
#  'each',
#  ' ',
#  'other',
#  '.',
#  '',
#  ' ',
#  'My',
#  ' ',
#  'own',
#  ' ',
#  'complete',
#  ' ',
#  'happiness',
#  ',',
#  '',
#  ' ',
#  'and',
#  ' ',
#  'the',
#  ' ',
#  'home-centred',
#  ' ',
#  'interests',
#  ' ',
#  'which',
#  ' ',
#  'rise',
#  ' ',
#  'up',
#  ' ',
#  'around',
#  ' ',
#  'the',
#  ' ',
#  'man',
#  ' ',
#  'who',
#  ' ',
#  'first',
#  ' ',
#  'finds',
#  ' ',
#  'himself',
#  ' ',
#  'master',
#  ' ',
#  'of',
#  ' ',
#  'his',
#  ' ',
#  'own',
#  ' ',
#  'establishment',
#  ',',
#  '',
#  ' ',
#  'were',
#  ' ',
#  'sufficient',
#  ' ',
#  'to',
#  ' ',
#  'absorb',
#  ' ',
#  'all',
#  ' ',
#  'my',
#  ' ',
#  'attention',
#  ',',
#  '',
#  ' ',
#  'while',
#  ' ',
#  'Holmes',
#  ',',
#  '',
#  ' ',
#  'who',
#  ' ',
#  'loathed',
#  ' ',
#  'every',
#  ' ',
#  'form',
#  ' ',
#  'of',
#  ' ',
#  'society',
#  ' ',
#  'with',
#  ' ',
#  'his',
#  ' ',
#  'whole',
#  ' ',
#  'Bohemian',
#  ' ',
#  'soul',
#  ',',
#  '',
#  ' ',
#  'remained',
#  ' ',
#  'in',
#  ' ',
#  'our',
#  ' ',
#  'lodgings',
#  ' ',
#  'in',
#  ' ',
#  'Baker',
#  ' ',
#  'Street',
#  ',',
#  '',
#  ' ',
#  'buried',
#  ' ',
#  'among',
#  ' ',
#  'his',
#  ' ',
#  'old',
#  ' ',
#  'books',
#  ',',
#  '',
#  ' ',
#  'and',
#  ' ',
#  'alternating',
#  ' ',
#  'from',
#  ' ',
#  'week',
#  ' ',
#  'to',
#  ' ',
#  'week',
#  ' ',
#  'between',
#  ' ',
#  'cocaine',
#  ' ',
#  'and',
#  ' ',
#  'ambition',
#  ',',
#  '',
#  ' ',
#  'the',
#  ' ',
#  'drowsiness',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'drug',
#  ',',
#  '',
#  ' ',
#  'and',
#  ' ',
#  'the',
#  ' ',
#  'fierce',
#  ' ',
#  'energy',
#  ' ',
#  'of',
#  ' ',
#  'his',
#  ' ',
#  'own',
#  ' ',
#  ...]

# %%
print("Number of tokens:", len(preprocessed))
# Out:
# Number of tokens: 258835

# %% [markdown]
# No. of Unique tokens in this dataset :8811

# %%
len(set(preprocessed))
# Out:
# 8811

# %% [markdown]
# After removing all of the starting punctuations

# %% [markdown]
#  Punctuations Removed Vocabulary

# %%
punctuations_removed_data = sorted(set(preprocessed))[98:8811]
punctuations_removed_data
# Out:
# ['A',
#  'ADLER',
#  'ADVENTURE',
#  'ARAT',
#  'Abbots',
#  'Aberdeen',
#  'About',
#  'Above',
#  'Absolute',
#  'Absolutely',
#  'Accustomed',
#  'Across',
#  'Adler',
#  'Adventure',
#  'Adventures',
#  'Affairs',
#  'Afghan',
#  'Afghanistan',
#  'After',
#  'Again',
#  'Agra',
#  'Ah',
#  'Air',
#  'Alas',
#  'Albert',
#  'Aldersgate',
#  'Aldershot',
#  'Alexander',
#  'Alice',
#  'Alicia',
#  'All',
#  'Allegro',
#  'Aloysius',
#  'Alpha',
#  'Already',
#  'Also',
#  'Altogether',
#  'Always',
#  'Amateur',
#  'America',
#  'American',
#  'Americans',
#  'Amid',
#  'Among',
#  'Amoy',
#  'Ample',
#  'An',
#  'And',
#  'Anderson',
#  'Andover',
#  'Angel',
#  'Another',
#  'Anstruther',
#  'Any',
#  'Anybody',
#  'Anyhow',
#  'Anything',
#  'Apache',
#  'Apaches',
#  'Apply',
#  'April',
#  'Arabian',
#  'Archery',
#  'Archie',
#  'Architecture',
#  'Are',
#  'Arizona',
#  'Armitage',
#  'Armour',
#  'Arms',
#  'Arnsworth',
#  'Arthur',
#  'Artillery',
#  'As',
#  'Assizes',
#  'Astonishment',
#  'At',
#  'Atkinson',
#  'Atlantic',
#  'Attica',
#  'Auckland',
#  'Augustine',
#  'Australia',
#  'Australian',
#  'Australians',
#  'Avenue',
#  'Awake',
#  'Away',
#  'Ay',
#  'Azure',
#  'B',
#  'BACHELOR',
#  'BALLARAT',
#  'BAND',
#  'BEECHES',
#  'BERYL',
#  'BLUE',
#  'BOHEMIA',
#  'BOSCOMBE',
#  'Bachelor',
#  'Backwater',
#  'Baker',
#  'Bakers',
#  'Ballarat',
#  'Balmoral',
#  'Balzac',
#  'Band',
#  'Bank',
#  'Bankers',
#  'Bar',
#  'Barque',
#  'Barton',
#  'Baxter',
#  'Be',
#  'Because',
#  'Becher',
#  'Beeches',
#  'Before',
#  'Behind',
#  'Bengal',
#  'Berkshire',
#  'Bermuda',
#  'Beryl',
#  'Beside',
#  'Besides',
#  'Better',
#  'Between',
#  'Beyond',
#  'Bible',
#  'Bill',
#  'Birchmoor',
#  'Black',
#  'Bloomsbury',
#  'Blue',
#  'Bohemia',
#  'Bohemian',
#  'Boone',
#  'Boots',
#  'Bordeaux',
#  'Born',
#  'Boscombe',
#  'Boswell',
#  'Botany',
#  'Both',
#  'Bought',
#  'Bow',
#  'Bradshaw',
#  'Bradstreet',
#  'Breckinridge',
#  'Bridge',
#  'Briefly',
#  'Bring',
#  'Briony',
#  'Bristol',
#  'Britain',
#  'Britannica',
#  'British',
#  'Brixton',
#  'Burnwell',
#  'But',
#  'By',
#  'By-the-way',
#  'C',
#  'CAN',
#  'CARBUNCLE',
#  'CASE',
#  'COPPER',
#  'CORONET',
#  'Cal',
#  'Calcutta',
#  'Calhoun',
#  'California',
#  'Californian',
#  'Camberwell',
#  'Can',
#  'Cannon',
#  'Capital',
#  'Captain',
#  'Carbuncle',
#  'Carefully',
#  'Carlo',
#  'Carlsbad',
#  'Carolinas',
#  'Case',
#  'Cassel-Felstein',
#  'Castle',
#  'Catherine',
#  'Cedars',
#  'Certainly',
#  'Chamber',
#  'Chance',
#  'Charing',
#  'Charles',
#  'Charming',
#  'Chesterfield',
#  'China',
#  'Chinese',
#  'Christ',
#  'Christmas',
#  'Chronicle',
#  'Chubb',
#  'Church',
#  'Circumstantial',
#  'City',
#  'Civil',
#  'Clair',
#  'Clara',
#  'Clark',
#  'Clay',
#  'Clearly',
#  'Close',
#  'Clotilde',
#  'Club',
#  'Co',
#  'Coarse',
#  'Cobb',
#  'Coburg',
#  'Cocksure',
#  'College',
#  'Colonel',
#  'Colony',
#  'Come',
#  'Coming',
#  'Commons',
#  'Company',
#  'Conan',
#  'Consider',
#  'Continent',
#  'Continental',
#  'Contralto',
#  'Convinced',
#  'Cooee',
#  'Cook',
#  'Copper',
#  'Cornwall',
#  'Coroner',
#  'Coronet',
#  'Cosmopolitan',
#  'Could',
#  'Count',
#  'Countess',
#  'Counties',
#  'Court',
#  'Covent',
#  'Coventry',
#  'Crane',
#  'Crewe',
#  'Crime',
#  'Cross',
#  'Crowder',
#  'Crown',
#  'Cusack',
#  'Cuvier',
#  'D',
#  'DEAR',
#  'DEAREST',
#  'DISSOLVED',
#  'Daily',
#  'Dane',
#  'Danger',
#  'Dark',
#  'Darlington',
#  'Data',
#  'Date',
#  'De',
#  'Dear',
#  'Dearest',
#  'Death',
#  'December',
#  'Deeply',
#  'Depend',
#  'Describe',
#  'Deserted',
#  'Devonshire',
#  'Did',
#  'Dirty',
#  'Disregarding',
#  'Division',
#  'Do',
#  'Dock',
#  'Dockyard',
#  'Doctor',
#  'Doctors',
#  'Does',
#  'Don',
#  'Done',
#  'Doran',
#  'Down',
#  'Doyle',
#  'Dr',
#  'Draw',
#  'Drink',
#  'Drive',
#  'Duchess',
#  'Duke',
#  'Duncan',
#  'Dundas',
#  'Dundee',
#  'During',
#  'E',
#  'ENGINEER',
#  'Each',
#  'Early',
#  'Easier',
#  'East',
#  'Eastern',
#  'Echo',
#  'Edgeware',
#  'Edward',
#  'Eg',
#  'Eglonitz',
#  'Eglow',
#  'Egria',
#  'Eh',
#  'Eight',
#  'Eley',
#  'Elias',
#  'Elise',
#  'Embankment',
#  'Encyclopaedia',
#  'End',
#  'Endell',
#  'Engineer',
#  'England',
#  'English',
#  'Englishman',
#  'Entirely',
#  'Esq',
#  'Etherege',
#  'Eton',
#  'Europe',
#  'European',
#  'Eustace',
#  'Even',
#  'Evening',
#  'Eventually',
#  'Every',
#  'Everybody',
#  'Evidence',
#  'Evidently',
#  'Exactly',
#  'Excellent',
#  'Except',
#  'Excuse',
#  'Experience',
#  'Extremely',
#  'Eyford',
#  'Ezekiah',
#  'F',
#  'FIVE',
#  'Faces',
#  'Fairbank',
#  'Fancy',
#  'Far',
#  'Fareham',
#  'Farewell',
#  'Farintosh',
#  'Farm',
#  'Farm-house',
#  'Farrington',
#  'Fashionable',
#  'Father',
#  'February',
#  'Fenchurch',
#  'Ferguson',
#  'Filled',
#  'Finally',
#  'Find',
#  'Fine',
#  'Finns',
#  'Fire',
#  'Five',
#  'Flaubert',
#  'Fleet',
#  'Flora',
#  'Florida',
#  'Folk',
#  'For',
#  'Fordham',
#  'Foreign',
#  'Forgery',
#  'Found',
#  'Four',
#  'Fowler',
#  'France',
#  'Francis',
#  'Francisco',
#  'Franco-Prussian',
#  'Frank',
#  'Frankly',
#  'Freebody',
#  'Freemason',
#  'Freemasonry',
#  'French',
#  'Frenchman',
#  'Frequently',
#  'Fresh',
#  'Fresno',
#  'Friday',
#  'Frisco',
#  'Fritz',
#  'From',
#  'G',
#  'Game',
#  'Gang',
#  'Garden',
#  'Gate',
#  'Gazetteer',
#  'George',
#  'Georgia',
#  'German',
#  'German-speaking',
#  'Germans',
#  'Gesellschaft',
#  'Get',
#  'Getting',
#  'Give',
#  'Giving',
#  'Gladstone',
#  'Globe',
#  'God',
#  'Godfrey',
#  'Gold',
#  'Gone',
#  'Good',
#  'Good-afternoon',
#  'Good-bye',
#  'Good-day',
#  'Good-evening',
#  'Good-morning',
#  'Good-night',
#  'Goodge',
#  'Goodwins',
#  'Gordon',
#  'Gottsreich',
#  'Grand',
#  'Grave',
#  'Gravesend',
#  'Great',
#  'Greenwich',
#  'Grice',
#  'Grimesby',
#  'Grit',
#  'Gross',
#  'Grosvenor',
#  'Gustave',
#  'H',
#  'HOLMES',
#  'HUNTER',
#  'Ha',
#  'Had',
#  'Hafiz',
#  'Hague',
#  'Half',
#  'Halifax',
#  'Hall',
#  'Hampshire',
#  'Hankey',
#  'Hanover',
#  'Hardy',
#  'Hare',
#  'Harley',
#  'Harris',
#  'Harrow',
#  'Has',
#  'Hatherley',
#  'Hatty',
#  'Have',
#  'Having',
#  'Hay',
#  'Hayling',
#  'He',
#  'Head',
#  'Heaven',
#  'Heavy',
#  'Hebrew',
#  'Heh',
#  'Helen',
#  'Hence',
#  'Henry',
#  'Her',
#  'Hercules',
#  'Here',
#  'Hereford',
#  'Herefordshire',
#  'Hers',
#  'High',
#  'Highness',
#  'Hill',
#  'His',
#  'Hitherto',
#  'Holborn',
#  'Hold',
#  'Holder',
#  'Holland',
#  'Holmes',
#  'Honoria',
#  'Hood',
#  'Hopkins',
#  'Horace',
#  'Horner',
#  'Horsham',
#  'Hosmer',
#  'Hotel',
#  'House',
#  'How',
#  'However',
#  'Hudson',
#  'Hugh',
#  'Hullo',
#  'Hum',
#  'Hunter',
#  'Hyde',
#  'I',
#  'IDENTITY',
#  'II',
#  'III',
#  'IN',
#  'IRENE',
#  'IS',
#  'IV',
#  'IX',
#  'Identity',
#  'If',
#  'Imagine',
#  'Imitated',
#  'Imperial',
#  'Impossible',
#  'In',
#  'Incredible',
#  'Indeed',
#  'India',
#  'Indian',
#  'Indians',
#  'Indirectly',
#  'Inn',
#  'Inner',
#  'Insensibly',
#  'Inspector',
#  'Instead',
#  'Irene',
#  'Irish-setter',
#  'Is',
#  'Isa',
#  'Isle',
#  'It',
#  'Italian',
#  'Its',
#  'J',
#  'JABEZ',
#  'JEPHRO',
#  'Jabez',
#  'Jack',
#  'Jack-in-office',
#  'Jackson',
#  'James',
#  'Jane',
#  'January',
#  'Jem',
#  'Jephro',
#  'Jeremiah',
#  'Jersey',
#  'Jewel',
#  'Jezail',
#  'John',
#  'Jones',
#  'Joseph',
#  'Jove',
#  'Julia',
#  'Jump',
#  'June',
#  'Juryman',
#  'Just',
#  'K',
#  'Kate',
#  'Keep',
#  'Kensington',
#  'Kent',
#  'Kilburn',
#  'Kill',
#  'Kindly',
#  'King',
#  'Klan',
#  'Klux',
#  'Knowing',
#  'Known',
#  'Kramm',
#  'Ku',
#  'L',
#  'LEAGUE',
#  'LIP',
#  'La',
#  'Lady',
#  'Lancaster',
#  'Lane',
#  'Langham',
#  'Large',
#  'Lascar',
#  'Last',
#  'Leadenhall',
#  'League',
#  'Leatherhead',
#  'Leave',
#  'Lebanon',
#  'Lee',
#  'Left',
#  'Lestrade',
#  'Let',
#  'Letters',
#  'Light',
#  'Lip',
#  'Listen',
#  'Living',
#  'Lloyd',
#  'Local',
#  'Lodge',
#  'Logic',
#  'London',
#  'Londoners',
#  'Lone',
#  'Look',
#  'Looking',
#  'Lord',
#  'Lordship',
#  'Lost',
#  'Lothman',
#  'Louisiana',
#  'Lucy',
#  'Lyon',
#  'Lysander',
#  'M',
#  'MAN',
#  'MARY',
#  'MISS',
#  'MR',
#  'MY',
#  'MYSTERY',
#  'Madame',
#  'Mademoiselle',
#  'Maggie',
#  'Majesty',
#  'Major',
#  'Major-General',
#  'Making',
#  'Malay',
#  'Male',
#  'Mall',
#  'Man',
#  'Manor',
#  'Mansions',
#  'Many',
#  'Marbank',
#  'March',
#  'Mark',
#  'Market',
#  'Married',
#  'Marseilles',
#  'Mary',
#  'Master',
#  'Matheson',
#  'Maudsley',
#  'Mauritius',
#  'May',
#  'McCarthy',
#  'McCarthys',
#  'McCauley',
#  'McFarlane',
#  'McQuire',
#  'Melbourne',
#  'Men',
#  'Mendicant',
#  'Meredith',
#  'Merryweather',
#  'Metropolitan',
#  'Mexico',
#  'Middlesex',
#  'Might',
#  'Millar',
#  'Miss',
#  'Missing',
#  'Mister',
#  'Monday',
#  'Monica',
#  'Montague',
#  'Montana',
#  'Moran',
#  'Morcar',
#  'More',
#  'Morning',
#  'Morris',
#  'Mortimer',
#  'Most',
#  'Mother',
#  'Moulton',
#  'Mr',
#  'Mrs',
#  'Munich',
#  'Munro',
#  'Murdered',
#  'Museum',
#  'Must',
#  'My',
#  'Mystery',
#  'NEVILLE',
#  'NOBLE',
#  'NORTON',
#  'Name',
#  'Naturally',
#  'Nature',
#  'Nay',
#  'Near',
#  'Nearly',
#  'Ned',
#  'Neither',
#  'Never',
#  'Neville',
#  'New',
#  'News',
#  'Next',
#  'Nights',
#  'No',
#  'Noble',
#  'Nonconformist',
#  'None',
#  'Nor',
#  'North',
#  'Northumberland',
#  'Norton',
#  'Not',
#  'Nothing',
#  'Nous',
#  'Nova',
#  'Now',
#  'O',
#  'OF',
#  'ORANGE',
#  'Oakshott',
#  'Obviously',
#  'Occurrence',
#  'Oct',
#  'October',
#  'Odessa',
#  'Of',
#  'Off',
#  'Office',
#  'Oh',
#  'Old',
#  'Omne',
#  'On',
#  'Once',
#  'One',
#  'Only',
#  'Opening',
#  'Openshaw',
#  'Opera',
#  'Or',
#  'Orange',
#  'Ordering',
#  'Ormstein',
#  'Oscillation',
#  'Others',
#  'Our',
#  'Out',
#  'Outside',
#  'Over',
#  'Owe',
#  'Oxford',
#  'Oxfordshire',
#  'P',
#  'PIPS',
#  'Pa',
#  'Pacific',
#  'Paddington',
#  'Pall',
#  'Palmer',
#  'Pancras',
#  'Papier',
#  'Paradol',
#  'Paramore',
#  'Paris',
#  'Park',
#  'Parr',
#  'Passing',
#  'Patersons',
#  'Patience',
#  'Paul',
#  'Peculiar',
#  'Pending',
#  'Pennsylvania',
#  'Pentonville',
#  'People',
#  'Percy',
#  'Perfectly',
#  'Perhaps',
#  'Persian',
#  'Peter',
#  'Petersfield',
#  'Peterson',
#  'Petrarch',
#  'Petrified',
#  'Philadelphia',
#  'Philosophy',
#  'Photography',
#  'Pink',
#  'Pips',
#  'Place',
#  'Plantagenet',
#  'Please',
#  'Police-Constable',
#  'Pon',
#  'Pondicherry',
#  'Pooh',
#  'Pool',
#  'Poor',
#  'Pope',
#  'Portsdown',
#  'Post',
#  'Posted',
#  'Prague',
#  'Pray',
#  'Precisely',
#  'Prendergast',
#  'Presently',
#  'Prima',
#  'Prince',
#  'Principal',
#  'Pritchard',
#  'Private',
#  'Probably',
#  'Problems',
#  'Proceed',
#  'Proosia',
#  'Prosper',
#  'Pshaw',
#  'Public',
#  'Publication',
#  'Put',
#  'Putting',
#  'Puzzle',
#  'Quick',
#  'Quincey',
#  'Quite',
#  'RED-HEADED',
#  'RUCASTLE',
#  'Rather',
#  'Read',
#  'Reading',
#  'Really',
#  'Recently',
#  'Red-headed',
#  'Regency',
#  'Regent',
#  'Remarkable',
#  'Remember',
#  'Republican',
#  'Restaurant',
#  'Retired',
#  'River',
#  'Road',
#  'Robbery',
#  'Robert',
#  'Robinson',
#  'Rockies',
#  'Ross',
#  'Rotterdam',
#  'Round',
#  'Roylott',
#  'Roylotts',
#  'Rucastle',
#  'Rucastles',
#  'Running',
#  'Russell',
#  'Russian',
#  'Ryder',
#  'S',
#  'SCANDAL',
#  'SHERLOCK',
#  'SIMON',
#  'SPECKLED',
#  'ST',
#  'Same',
#  'San',
#  'Sand',
#  'Sarasate',
#  'Saturday',
#  'Savannah',
#  'Save',
#  'Saviour',
#  'Saxe-Coburg',
#  'Saxe-Meningen',
#  'Saxon',
#  'Scala',
#  'Scandal',
#  'Scandinavia',
#  'Scarlet',
#  'Scotch',
#  'Scotia',
#  'Scotland',
#  'Scott',
#  'Secretary',
#  'See',
#  'Seeing',
#  'Seldom',
#  'Send',
#  'September',
#  'Serpentine',
#  'Serpentine-mews',
#  'Set',
#  'Seven',
#  'Several',
#  'Severn',
#  'Shall',
#  'She',
#  'Sherlock',
#  'Shillings',
#  'Shipping',
#  'Sholto',
#  'Sholtos',
#  'Shortly',
#  'Should',
#  'Showing',
#  'Sigismond',
#  'Sign',
#  'Simon',
#  'Since',
#  'Singular',
#  'Singularity',
#  'Sir',
#  'Sit',
#  'Six',
#  'Slipping',
#  'Slowly',
#  'Smack',
#  'Small',
#  'Smart',
#  'Snapping',
#  'So',
#  'Society',
#  'Sold',
#  'Some',
#  'Someone',
#  'Something',
#  'Sometimes',
#  'Sophy',
#  'South',
#  'Southampton',
#  'Southern',
#  'Southerton',
#  'Spaulding',
#  'Speckled',
#  'Spence',
#  'Spies',
#  'Square',
#  'St',
#  'Standard',
#  'Star',
#  'Stark',
#  'Stars',
#  'Starving',
#  'States',
#  'Station',
#  'Stay',
#  'Step',
#  'Stevenson',
#  'Still',
#  'Stoke',
#  'Stolen',
#  'Stoner',
#  'Stop',
#  'Stoper',
#  'Strand',
#  'Streatham',
#  'Street',
#  'Striding',
#  'Stripes',
#  'Stroud',
#  'Study',
#  'Subtle',
#  'Suburban',
#  'Such',
#  'Suddenly',
#  'Sunday-school',
#  'Suppose',
#  'Supposing',
#  'Surely',
#  'Surrey',
#  'Sussex',
#  'Sutherland',
#  'Swain',
#  'Swan',
#  'Swandam',
#  'Swiftly',
#  'Swindon',
#  'THE',
#  'THUMB',
#  'TO',
#  'TWISTED',
#  'Take',
#  'Tankerville',
#  'Telegraph',
#  ...]

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # 2.2 Converting tokens into token IDs

# %% [markdown]
# - Next, we convert the text tokens into token IDs that we can process via embedding layers later
# - For this we first need to build a vocabulary

# %% [markdown]
# <img src="figures/04.png" width="900px">

# %% [markdown]
# - The vocabulary contains the unique words in the input text

# %%
all_words = sorted(set(punctuations_removed_data))
vocab_size = len(all_words)

print(vocab_size)
# Out:
# 8713

# %%
for i in enumerate(punctuations_removed_data):
    print(i)
# Out:
# (0, 'A')
# (1, 'ADLER')
# (2, 'ADVENTURE')
# (3, 'ARAT')
# (4, 'Abbots')
# (5, 'Aberdeen')
# (6, 'About')
# (7, 'Above')
# (8, 'Absolute')
# (9, 'Absolutely')
# (10, 'Accustomed')
# (11, 'Across')
# (12, 'Adler')
# (13, 'Adventure')
# (14, 'Adventures')
# (15, 'Affairs')
# (16, 'Afghan')
# (17, 'Afghanistan')
# (18, 'After')
# (19, 'Again')
# (20, 'Agra')
# (21, 'Ah')
# (22, 'Air')
# (23, 'Alas')
# (24, 'Albert')
# (25, 'Aldersgate')
# (26, 'Aldershot')
# (27, 'Alexander')
# (28, 'Alice')
# (29, 'Alicia')
# (30, 'All')
# (31, 'Allegro')
# (32, 'Aloysius')
# (33, 'Alpha')
# (34, 'Already')
# (35, 'Also')
# (36, 'Altogether')
# (37, 'Always')
# (38, 'Amateur')
# (39, 'America')
# (40, 'American')
# (41, 'Americans')
# (42, 'Amid')
# (43, 'Among')
# (44, 'Amoy')
# (45, 'Ample')
# (46, 'An')
# (47, 'And')
# (48, 'Anderson')
# (49, 'Andover')
# (50, 'Angel')
# (51, 'Another')
# (52, 'Anstruther')
# (53, 'Any')
# (54, 'Anybody')
# (55, 'Anyhow')
# (56, 'Anything')
# (57, 'Apache')
# (58, 'Apaches')
# (59, 'Apply')
# (60, 'April')
# (61, 'Arabian')
# (62, 'Archery')
# (63, 'Archie')
# (64, 'Architecture')
# (65, 'Are')
# (66, 'Arizona')
# (67, 'Armitage')
# (68, 'Armour')
# (69, 'Arms')
# (70, 'Arnsworth')
# (71, 'Arthur')
# (72, 'Artillery')
# (73, 'As')
# (74, 'Assizes')
# (75, 'Astonishment')
# (76, 'At')
# (77, 'Atkinson')
# (78, 'Atlantic')
# (79, 'Attica')
# (80, 'Auckland')
# (81, 'Augustine')
# (82, 'Australia')
# (83, 'Australian')
# (84, 'Australians')
# (85, 'Avenue')
# (86, 'Awake')
# (87, 'Away')
# (88, 'Ay')
# (89, 'Azure')
# (90, 'B')
# (91, 'BACHELOR')
# (92, 'BALLARAT')
# (93, 'BAND')
# (94, 'BEECHES')
# (95, 'BERYL')
# (96, 'BLUE')
# (97, 'BOHEMIA')
# (98, 'BOSCOMBE')
# (99, 'Bachelor')
# (100, 'Backwater')
# (101, 'Baker')
# (102, 'Bakers')
# (103, 'Ballarat')
# (104, 'Balmoral')
# (105, 'Balzac')
# (106, 'Band')
# (107, 'Bank')
# (108, 'Bankers')
# (109, 'Bar')
# (110, 'Barque')
# (111, 'Barton')
# (112, 'Baxter')
# (113, 'Be')
# (114, 'Because')
# (115, 'Becher')
# (116, 'Beeches')
# (117, 'Before')
# (118, 'Behind')
# (119, 'Bengal')
# (120, 'Berkshire')
# (121, 'Bermuda')
# (122, 'Beryl')
# (123, 'Beside')
# (124, 'Besides')
# (125, 'Better')
# (126, 'Between')
# (127, 'Beyond')
# (128, 'Bible')
# (129, 'Bill')
# (130, 'Birchmoor')
# (131, 'Black')
# (132, 'Bloomsbury')
# (133, 'Blue')
# (134, 'Bohemia')
# (135, 'Bohemian')
# (136, 'Boone')
# (137, 'Boots')
# (138, 'Bordeaux')
# (139, 'Born')
# (140, 'Boscombe')
# (141, 'Boswell')
# (142, 'Botany')
# (143, 'Both')
# (144, 'Bought')
# (145, 'Bow')
# (146, 'Bradshaw')
# (147, 'Bradstreet')
# (148, 'Breckinridge')
# (149, 'Bridge')
# (150, 'Briefly')
# (151, 'Bring')
# (152, 'Briony')
# (153, 'Bristol')
# (154, 'Britain')
# (155, 'Britannica')
# (156, 'British')
# (157, 'Brixton')
# (158, 'Burnwell')
# (159, 'But')
# (160, 'By')
# (161, 'By-the-way')
# (162, 'C')
# (163, 'CAN')
# (164, 'CARBUNCLE')
# (165, 'CASE')
# (166, 'COPPER')
# (167, 'CORONET')
# (168, 'Cal')
# (169, 'Calcutta')
# (170, 'Calhoun')
# (171, 'California')
# (172, 'Californian')
# (173, 'Camberwell')
# (174, 'Can')
# (175, 'Cannon')
# (176, 'Capital')
# (177, 'Captain')
# (178, 'Carbuncle')
# (179, 'Carefully')
# (180, 'Carlo')
# (181, 'Carlsbad')
# (182, 'Carolinas')
# (183, 'Case')
# (184, 'Cassel-Felstein')
# (185, 'Castle')
# (186, 'Catherine')
# (187, 'Cedars')
# (188, 'Certainly')
# (189, 'Chamber')
# (190, 'Chance')
# (191, 'Charing')
# (192, 'Charles')
# (193, 'Charming')
# (194, 'Chesterfield')
# (195, 'China')
# (196, 'Chinese')
# (197, 'Christ')
# (198, 'Christmas')
# (199, 'Chronicle')
# (200, 'Chubb')
# (201, 'Church')
# (202, 'Circumstantial')
# (203, 'City')
# (204, 'Civil')
# (205, 'Clair')
# (206, 'Clara')
# (207, 'Clark')
# (208, 'Clay')
# (209, 'Clearly')
# (210, 'Close')
# (211, 'Clotilde')
# (212, 'Club')
# (213, 'Co')
# (214, 'Coarse')
# (215, 'Cobb')
# (216, 'Coburg')
# (217, 'Cocksure')
# (218, 'College')
# (219, 'Colonel')
# (220, 'Colony')
# (221, 'Come')
# (222, 'Coming')
# (223, 'Commons')
# (224, 'Company')
# (225, 'Conan')
# (226, 'Consider')
# (227, 'Continent')
# (228, 'Continental')
# (229, 'Contralto')
# (230, 'Convinced')
# (231, 'Cooee')
# (232, 'Cook')
# (233, 'Copper')
# (234, 'Cornwall')
# (235, 'Coroner')
# (236, 'Coronet')
# (237, 'Cosmopolitan')
# (238, 'Could')
# (239, 'Count')
# (240, 'Countess')
# (241, 'Counties')
# (242, 'Court')
# (243, 'Covent')
# (244, 'Coventry')
# (245, 'Crane')
# (246, 'Crewe')
# (247, 'Crime')
# (248, 'Cross')
# (249, 'Crowder')
# (250, 'Crown')
# (251, 'Cusack')
# (252, 'Cuvier')
# (253, 'D')
# (254, 'DEAR')
# (255, 'DEAREST')
# (256, 'DISSOLVED')
# (257, 'Daily')
# (258, 'Dane')
# (259, 'Danger')
# (260, 'Dark')
# (261, 'Darlington')
# (262, 'Data')
# (263, 'Date')
# (264, 'De')
# (265, 'Dear')
# (266, 'Dearest')
# (267, 'Death')
# (268, 'December')
# (269, 'Deeply')
# (270, 'Depend')
# (271, 'Describe')
# (272, 'Deserted')
# (273, 'Devonshire')
# (274, 'Did')
# (275, 'Dirty')
# (276, 'Disregarding')
# (277, 'Division')
# (278, 'Do')
# (279, 'Dock')
# (280, 'Dockyard')
# (281, 'Doctor')
# (282, 'Doctors')
# (283, 'Does')
# (284, 'Don')
# (285, 'Done')
# (286, 'Doran')
# (287, 'Down')
# (288, 'Doyle')
# (289, 'Dr')
# (290, 'Draw')
# (291, 'Drink')
# (292, 'Drive')
# (293, 'Duchess')
# (294, 'Duke')
# (295, 'Duncan')
# (296, 'Dundas')
# (297, 'Dundee')
# (298, 'During')
# (299, 'E')
# (300, 'ENGINEER')
# (301, 'Each')
# (302, 'Early')
# (303, 'Easier')
# (304, 'East')
# (305, 'Eastern')
# (306, 'Echo')
# (307, 'Edgeware')
# (308, 'Edward')
# (309, 'Eg')
# (310, 'Eglonitz')
# (311, 'Eglow')
# (312, 'Egria')
# (313, 'Eh')
# (314, 'Eight')
# (315, 'Eley')
# (316, 'Elias')
# (317, 'Elise')
# (318, 'Embankment')
# (319, 'Encyclopaedia')
# (320, 'End')
# (321, 'Endell')
# (322, 'Engineer')
# (323, 'England')
# (324, 'English')
# (325, 'Englishman')
# (326, 'Entirely')
# (327, 'Esq')
# (328, 'Etherege')
# (329, 'Eton')
# (330, 'Europe')
# (331, 'European')
# (332, 'Eustace')
# (333, 'Even')
# (334, 'Evening')
# (335, 'Eventually')
# (336, 'Every')
# (337, 'Everybody')
# (338, 'Evidence')
# (339, 'Evidently')
# (340, 'Exactly')
# (341, 'Excellent')
# (342, 'Except')
# (343, 'Excuse')
# (344, 'Experience')
# (345, 'Extremely')
# (346, 'Eyford')
# (347, 'Ezekiah')
# (348, 'F')
# (349, 'FIVE')
# (350, 'Faces')
# (351, 'Fairbank')
# (352, 'Fancy')
# (353, 'Far')
# (354, 'Fareham')
# (355, 'Farewell')
# (356, 'Farintosh')
# (357, 'Farm')
# (358, 'Farm-house')
# (359, 'Farrington')
# (360, 'Fashionable')
# (361, 'Father')
# (362, 'February')
# (363, 'Fenchurch')
# (364, 'Ferguson')
# (365, 'Filled')
# (366, 'Finally')
# (367, 'Find')
# (368, 'Fine')
# (369, 'Finns')
# (370, 'Fire')
# (371, 'Five')
# (372, 'Flaubert')
# (373, 'Fleet')
# (374, 'Flora')
# (375, 'Florida')
# (376, 'Folk')
# (377, 'For')
# (378, 'Fordham')
# (379, 'Foreign')
# (380, 'Forgery')
# (381, 'Found')
# (382, 'Four')
# (383, 'Fowler')
# (384, 'France')
# (385, 'Francis')
# (386, 'Francisco')
# (387, 'Franco-Prussian')
# (388, 'Frank')
# (389, 'Frankly')
# (390, 'Freebody')
# (391, 'Freemason')
# (392, 'Freemasonry')
# (393, 'French')
# (394, 'Frenchman')
# (395, 'Frequently')
# (396, 'Fresh')
# (397, 'Fresno')
# (398, 'Friday')
# (399, 'Frisco')
# (400, 'Fritz')
# (401, 'From')
# (402, 'G')
# (403, 'Game')
# (404, 'Gang')
# (405, 'Garden')
# (406, 'Gate')
# (407, 'Gazetteer')
# (408, 'George')
# (409, 'Georgia')
# (410, 'German')
# (411, 'German-speaking')
# (412, 'Germans')
# (413, 'Gesellschaft')
# (414, 'Get')
# (415, 'Getting')
# (416, 'Give')
# (417, 'Giving')
# (418, 'Gladstone')
# (419, 'Globe')
# (420, 'God')
# (421, 'Godfrey')
# (422, 'Gold')
# (423, 'Gone')
# (424, 'Good')
# (425, 'Good-afternoon')
# (426, 'Good-bye')
# (427, 'Good-day')
# (428, 'Good-evening')
# (429, 'Good-morning')
# (430, 'Good-night')
# (431, 'Goodge')
# (432, 'Goodwins')
# (433, 'Gordon')
# (434, 'Gottsreich')
# (435, 'Grand')
# (436, 'Grave')
# (437, 'Gravesend')
# (438, 'Great')
# (439, 'Greenwich')
# (440, 'Grice')
# (441, 'Grimesby')
# (442, 'Grit')
# (443, 'Gross')
# (444, 'Grosvenor')
# (445, 'Gustave')
# (446, 'H')
# (447, 'HOLMES')
# (448, 'HUNTER')
# (449, 'Ha')
# (450, 'Had')
# (451, 'Hafiz')
# (452, 'Hague')
# (453, 'Half')
# (454, 'Halifax')
# (455, 'Hall')
# (456, 'Hampshire')
# (457, 'Hankey')
# (458, 'Hanover')
# (459, 'Hardy')
# (460, 'Hare')
# (461, 'Harley')
# (462, 'Harris')
# (463, 'Harrow')
# (464, 'Has')
# (465, 'Hatherley')
# (466, 'Hatty')
# (467, 'Have')
# (468, 'Having')
# (469, 'Hay')
# (470, 'Hayling')
# (471, 'He')
# (472, 'Head')
# (473, 'Heaven')
# (474, 'Heavy')
# (475, 'Hebrew')
# (476, 'Heh')
# (477, 'Helen')
# (478, 'Hence')
# (479, 'Henry')
# (480, 'Her')
# (481, 'Hercules')
# (482, 'Here')
# (483, 'Hereford')
# (484, 'Herefordshire')
# (485, 'Hers')
# (486, 'High')
# (487, 'Highness')
# (488, 'Hill')
# (489, 'His')
# (490, 'Hitherto')
# (491, 'Holborn')
# (492, 'Hold')
# (493, 'Holder')
# (494, 'Holland')
# (495, 'Holmes')
# (496, 'Honoria')
# (497, 'Hood')
# (498, 'Hopkins')
# (499, 'Horace')
# (500, 'Horner')
# (501, 'Horsham')
# (502, 'Hosmer')
# (503, 'Hotel')
# (504, 'House')
# (505, 'How')
# (506, 'However')
# (507, 'Hudson')
# (508, 'Hugh')
# (509, 'Hullo')
# (510, 'Hum')
# (511, 'Hunter')
# (512, 'Hyde')
# (513, 'I')
# (514, 'IDENTITY')
# (515, 'II')
# (516, 'III')
# (517, 'IN')
# (518, 'IRENE')
# (519, 'IS')
# (520, 'IV')
# (521, 'IX')
# (522, 'Identity')
# (523, 'If')
# (524, 'Imagine')
# (525, 'Imitated')
# (526, 'Imperial')
# (527, 'Impossible')
# (528, 'In')
# (529, 'Incredible')
# (530, 'Indeed')
# (531, 'India')
# (532, 'Indian')
# (533, 'Indians')
# (534, 'Indirectly')
# (535, 'Inn')
# (536, 'Inner')
# (537, 'Insensibly')
# (538, 'Inspector')
# (539, 'Instead')
# (540, 'Irene')
# (541, 'Irish-setter')
# (542, 'Is')
# (543, 'Isa')
# (544, 'Isle')
# (545, 'It')
# (546, 'Italian')
# (547, 'Its')
# (548, 'J')
# (549, 'JABEZ')
# (550, 'JEPHRO')
# (551, 'Jabez')
# (552, 'Jack')
# (553, 'Jack-in-office')
# (554, 'Jackson')
# (555, 'James')
# (556, 'Jane')
# (557, 'January')
# (558, 'Jem')
# (559, 'Jephro')
# (560, 'Jeremiah')
# (561, 'Jersey')
# (562, 'Jewel')
# (563, 'Jezail')
# (564, 'John')
# (565, 'Jones')
# (566, 'Joseph')
# (567, 'Jove')
# (568, 'Julia')
# (569, 'Jump')
# (570, 'June')
# (571, 'Juryman')
# (572, 'Just')
# (573, 'K')
# (574, 'Kate')
# (575, 'Keep')
# (576, 'Kensington')
# (577, 'Kent')
# (578, 'Kilburn')
# (579, 'Kill')
# (580, 'Kindly')
# (581, 'King')
# (582, 'Klan')
# (583, 'Klux')
# (584, 'Knowing')
# (585, 'Known')
# (586, 'Kramm')
# (587, 'Ku')
# (588, 'L')
# (589, 'LEAGUE')
# (590, 'LIP')
# (591, 'La')
# (592, 'Lady')
# (593, 'Lancaster')
# (594, 'Lane')
# (595, 'Langham')
# (596, 'Large')
# (597, 'Lascar')
# (598, 'Last')
# (599, 'Leadenhall')
# (600, 'League')
# (601, 'Leatherhead')
# (602, 'Leave')
# (603, 'Lebanon')
# (604, 'Lee')
# (605, 'Left')
# (606, 'Lestrade')
# (607, 'Let')
# (608, 'Letters')
# (609, 'Light')
# (610, 'Lip')
# (611, 'Listen')
# (612, 'Living')
# (613, 'Lloyd')
# (614, 'Local')
# (615, 'Lodge')
# (616, 'Logic')
# (617, 'London')
# (618, 'Londoners')
# (619, 'Lone')
# (620, 'Look')
# (621, 'Looking')
# (622, 'Lord')
# (623, 'Lordship')
# (624, 'Lost')
# (625, 'Lothman')
# (626, 'Louisiana')
# (627, 'Lucy')
# (628, 'Lyon')
# (629, 'Lysander')
# (630, 'M')
# (631, 'MAN')
# (632, 'MARY')
# (633, 'MISS')
# (634, 'MR')
# (635, 'MY')
# (636, 'MYSTERY')
# (637, 'Madame')
# (638, 'Mademoiselle')
# (639, 'Maggie')
# (640, 'Majesty')
# (641, 'Major')
# (642, 'Major-General')
# (643, 'Making')
# (644, 'Malay')
# (645, 'Male')
# (646, 'Mall')
# (647, 'Man')
# (648, 'Manor')
# (649, 'Mansions')
# (650, 'Many')
# (651, 'Marbank')
# (652, 'March')
# (653, 'Mark')
# (654, 'Market')
# (655, 'Married')
# (656, 'Marseilles')
# (657, 'Mary')
# (658, 'Master')
# (659, 'Matheson')
# (660, 'Maudsley')
# (661, 'Mauritius')
# (662, 'May')
# (663, 'McCarthy')
# (664, 'McCarthys')
# (665, 'McCauley')
# (666, 'McFarlane')
# (667, 'McQuire')
# (668, 'Melbourne')
# (669, 'Men')
# (670, 'Mendicant')
# (671, 'Meredith')
# (672, 'Merryweather')
# (673, 'Metropolitan')
# (674, 'Mexico')
# (675, 'Middlesex')
# (676, 'Might')
# (677, 'Millar')
# (678, 'Miss')
# (679, 'Missing')
# (680, 'Mister')
# (681, 'Monday')
# (682, 'Monica')
# (683, 'Montague')
# (684, 'Montana')
# (685, 'Moran')
# (686, 'Morcar')
# (687, 'More')
# (688, 'Morning')
# (689, 'Morris')
# (690, 'Mortimer')
# (691, 'Most')
# (692, 'Mother')
# (693, 'Moulton')
# (694, 'Mr')
# (695, 'Mrs')
# (696, 'Munich')
# (697, 'Munro')
# (698, 'Murdered')
# (699, 'Museum')
# (700, 'Must')
# (701, 'My')
# (702, 'Mystery')
# (703, 'NEVILLE')
# (704, 'NOBLE')
# (705, 'NORTON')
# (706, 'Name')
# (707, 'Naturally')
# (708, 'Nature')
# (709, 'Nay')
# (710, 'Near')
# (711, 'Nearly')
# (712, 'Ned')
# (713, 'Neither')
# (714, 'Never')
# (715, 'Neville')
# (716, 'New')
# (717, 'News')
# (718, 'Next')
# (719, 'Nights')
# (720, 'No')
# (721, 'Noble')
# (722, 'Nonconformist')
# (723, 'None')
# (724, 'Nor')
# (725, 'North')
# (726, 'Northumberland')
# (727, 'Norton')
# (728, 'Not')
# (729, 'Nothing')
# (730, 'Nous')
# (731, 'Nova')
# (732, 'Now')
# (733, 'O')
# (734, 'OF')
# (735, 'ORANGE')
# (736, 'Oakshott')
# (737, 'Obviously')
# (738, 'Occurrence')
# (739, 'Oct')
# (740, 'October')
# (741, 'Odessa')
# (742, 'Of')
# (743, 'Off')
# (744, 'Office')
# (745, 'Oh')
# (746, 'Old')
# (747, 'Omne')
# (748, 'On')
# (749, 'Once')
# (750, 'One')
# (751, 'Only')
# (752, 'Opening')
# (753, 'Openshaw')
# (754, 'Opera')
# (755, 'Or')
# (756, 'Orange')
# (757, 'Ordering')
# (758, 'Ormstein')
# (759, 'Oscillation')
# (760, 'Others')
# (761, 'Our')
# (762, 'Out')
# (763, 'Outside')
# (764, 'Over')
# (765, 'Owe')
# (766, 'Oxford')
# (767, 'Oxfordshire')
# (768, 'P')
# (769, 'PIPS')
# (770, 'Pa')
# (771, 'Pacific')
# (772, 'Paddington')
# (773, 'Pall')
# (774, 'Palmer')
# (775, 'Pancras')
# (776, 'Papier')
# (777, 'Paradol')
# (778, 'Paramore')
# (779, 'Paris')
# (780, 'Park')
# (781, 'Parr')
# (782, 'Passing')
# (783, 'Patersons')
# (784, 'Patience')
# (785, 'Paul')
# (786, 'Peculiar')
# (787, 'Pending')
# (788, 'Pennsylvania')
# (789, 'Pentonville')
# (790, 'People')
# (791, 'Percy')
# (792, 'Perfectly')
# (793, 'Perhaps')
# (794, 'Persian')
# (795, 'Peter')
# (796, 'Petersfield')
# (797, 'Peterson')
# (798, 'Petrarch')
# (799, 'Petrified')
# (800, 'Philadelphia')
# (801, 'Philosophy')
# (802, 'Photography')
# (803, 'Pink')
# (804, 'Pips')
# (805, 'Place')
# (806, 'Plantagenet')
# (807, 'Please')
# (808, 'Police-Constable')
# (809, 'Pon')
# (810, 'Pondicherry')
# (811, 'Pooh')
# (812, 'Pool')
# (813, 'Poor')
# (814, 'Pope')
# (815, 'Portsdown')
# (816, 'Post')
# (817, 'Posted')
# (818, 'Prague')
# (819, 'Pray')
# (820, 'Precisely')
# (821, 'Prendergast')
# (822, 'Presently')
# (823, 'Prima')
# (824, 'Prince')
# (825, 'Principal')
# (826, 'Pritchard')
# (827, 'Private')
# (828, 'Probably')
# (829, 'Problems')
# (830, 'Proceed')
# (831, 'Proosia')
# (832, 'Prosper')
# (833, 'Pshaw')
# (834, 'Public')
# (835, 'Publication')
# (836, 'Put')
# (837, 'Putting')
# (838, 'Puzzle')
# (839, 'Quick')
# (840, 'Quincey')
# (841, 'Quite')
# (842, 'RED-HEADED')
# (843, 'RUCASTLE')
# (844, 'Rather')
# (845, 'Read')
# (846, 'Reading')
# (847, 'Really')
# (848, 'Recently')
# (849, 'Red-headed')
# (850, 'Regency')
# (851, 'Regent')
# (852, 'Remarkable')
# (853, 'Remember')
# (854, 'Republican')
# (855, 'Restaurant')
# (856, 'Retired')
# (857, 'River')
# (858, 'Road')
# (859, 'Robbery')
# (860, 'Robert')
# (861, 'Robinson')
# (862, 'Rockies')
# (863, 'Ross')
# (864, 'Rotterdam')
# (865, 'Round')
# (866, 'Roylott')
# (867, 'Roylotts')
# (868, 'Rucastle')
# (869, 'Rucastles')
# (870, 'Running')
# (871, 'Russell')
# (872, 'Russian')
# (873, 'Ryder')
# (874, 'S')
# (875, 'SCANDAL')
# (876, 'SHERLOCK')
# (877, 'SIMON')
# (878, 'SPECKLED')
# (879, 'ST')
# (880, 'Same')
# (881, 'San')
# (882, 'Sand')
# (883, 'Sarasate')
# (884, 'Saturday')
# (885, 'Savannah')
# (886, 'Save')
# (887, 'Saviour')
# (888, 'Saxe-Coburg')
# (889, 'Saxe-Meningen')
# (890, 'Saxon')
# (891, 'Scala')
# (892, 'Scandal')
# (893, 'Scandinavia')
# (894, 'Scarlet')
# (895, 'Scotch')
# (896, 'Scotia')
# (897, 'Scotland')
# (898, 'Scott')
# (899, 'Secretary')
# (900, 'See')
# (901, 'Seeing')
# (902, 'Seldom')
# (903, 'Send')
# (904, 'September')
# (905, 'Serpentine')
# (906, 'Serpentine-mews')
# (907, 'Set')
# (908, 'Seven')
# (909, 'Several')
# (910, 'Severn')
# (911, 'Shall')
# (912, 'She')
# (913, 'Sherlock')
# (914, 'Shillings')
# (915, 'Shipping')
# (916, 'Sholto')
# (917, 'Sholtos')
# (918, 'Shortly')
# (919, 'Should')
# (920, 'Showing')
# (921, 'Sigismond')
# (922, 'Sign')
# (923, 'Simon')
# (924, 'Since')
# (925, 'Singular')
# (926, 'Singularity')
# (927, 'Sir')
# (928, 'Sit')
# (929, 'Six')
# (930, 'Slipping')
# (931, 'Slowly')
# (932, 'Smack')
# (933, 'Small')
# (934, 'Smart')
# (935, 'Snapping')
# (936, 'So')
# (937, 'Society')
# (938, 'Sold')
# (939, 'Some')
# (940, 'Someone')
# (941, 'Something')
# (942, 'Sometimes')
# (943, 'Sophy')
# (944, 'South')
# (945, 'Southampton')
# (946, 'Southern')
# (947, 'Southerton')
# (948, 'Spaulding')
# (949, 'Speckled')
# (950, 'Spence')
# (951, 'Spies')
# (952, 'Square')
# (953, 'St')
# (954, 'Standard')
# (955, 'Star')
# (956, 'Stark')
# (957, 'Stars')
# (958, 'Starving')
# (959, 'States')
# (960, 'Station')
# (961, 'Stay')
# (962, 'Step')
# (963, 'Stevenson')
# (964, 'Still')
# (965, 'Stoke')
# (966, 'Stolen')
# (967, 'Stoner')
# (968, 'Stop')
# (969, 'Stoper')
# (970, 'Strand')
# (971, 'Streatham')
# (972, 'Street')
# (973, 'Striding')
# (974, 'Stripes')
# (975, 'Stroud')
# (976, 'Study')
# (977, 'Subtle')
# (978, 'Suburban')
# (979, 'Such')
# (980, 'Suddenly')
# (981, 'Sunday-school')
# (982, 'Suppose')
# (983, 'Supposing')
# (984, 'Surely')
# (985, 'Surrey')
# (986, 'Sussex')
# (987, 'Sutherland')
# (988, 'Swain')
# (989, 'Swan')
# (990, 'Swandam')
# (991, 'Swiftly')
# (992, 'Swindon')
# (993, 'THE')
# (994, 'THUMB')
# (995, 'TO')
# (996, 'TWISTED')
# (997, 'Take')
# (998, 'Tankerville')
# (999, 'Telegraph')
# (1000, 'Tell')
# (1001, 'Temple')
# (1002, 'Ten')
# (1003, 'Tennessee')
# (1004, 'Terrible')
# (1005, 'Terse')
# (1006, 'Testament')
# (1007, 'Texas')
# (1008, 'Thames')
# (1009, 'Thank')
# (1010, 'That')
# (1011, 'The')
# (1012, 'Their')
# (1013, 'Then')
# (1014, 'Theological')
# (1015, 'Theories')
# (1016, 'There')
# (1017, 'Therefore')
# (1018, 'Therein')
# (1019, 'These')
# (1020, 'They')
# (1021, 'Thick')
# (1022, 'Think')
# (1023, 'Third')
# (1024, 'This')
# (1025, 'Thoreau')
# (1026, 'Those')
# (1027, 'Though')
# (1028, 'Threadneedle')
# (1029, 'Threatens')
# (1030, 'Three')
# (1031, 'Through')
# (1032, 'Thrust')
# (1033, 'Thumb')
# (1034, 'Thursday')
# (1035, 'Times')
# (1036, 'Tiptoes')
# (1037, 'Tired-looking')
# (1038, 'To')
# (1039, 'To-day')
# (1040, 'To-morrow')
# (1041, 'Together')
# (1042, 'Toller')
# (1043, 'Tollers')
# (1044, 'Too')
# (1045, 'Tottenham')
# (1046, 'Tottering')
# (1047, 'Trafalgar')
# (1048, 'Tragedy')
# (1049, 'Trepoff')
# (1050, 'Trincomalee')
# (1051, 'Try')
# (1052, 'Tudor')
# (1053, 'Tuesday')
# (1054, 'Turkish')
# (1055, 'Turn')
# (1056, 'Turner')
# (1057, 'Turning')
# (1058, 'Tut')
# (1059, 'Twelve')
# (1060, 'Twenty-four')
# (1061, 'Twenty-nine')
# (1062, 'Twice')
# (1063, 'Twisted')
# (1064, 'Two')
# (1065, 'U')
# (1066, 'UNCLE')
# (1067, 'Uffa')
# (1068, 'Under')
# (1069, 'Under-Secretary')
# (1070, 'Underground')
# (1071, 'Undoubtedly')
# (1072, 'Union')
# (1073, 'United')
# (1074, 'Unless')
# (1075, 'Until')
# (1076, 'Up')
# (1077, 'Upon')
# (1078, 'Upper')
# (1079, 'V')
# (1080, 'VALLEY')
# (1081, 'VI')
# (1082, 'VII')
# (1083, 'VIII')
# (1084, 'VIOLET')
# (1085, 'Valley')
# (1086, 'Vegetarian')
# (1087, 'Venner')
# (1088, 'Vere')
# (1089, 'Very')
# (1090, 'Victor')
# (1091, 'Victoria')
# (1092, 'Vincent')
# (1093, 'Violence')
# (1094, 'Violet')
# (1095, 'Visited')
# (1096, 'Voilà')
# (1097, 'Von')
# (1098, 'WILSON')
# (1099, 'WITH')
# (1100, 'Wait')
# (1101, 'Walk')
# (1102, 'Wallenstein')
# (1103, 'Walsall')
# (1104, 'Walsingham')
# (1105, 'War')
# (1106, 'Warburton')
# (1107, 'Warm')
# (1108, 'Warsaw')
# (1109, 'Was')
# (1110, 'Water')
# (1111, 'Waterloo')
# (1112, 'Watson')
# (1113, 'We')
# (1114, 'Wedding')
# (1115, 'Wedlock')
# (1116, 'Wednesday')
# (1117, 'Well')
# (1118, 'Wellington')
# (1119, 'Were')
# (1120, 'West')
# (1121, 'Westaway')
# (1122, 'Westbury')
# (1123, 'Westhouse')
# (1124, 'Westphail')
# (1125, 'Wharf')
# (1126, 'What')
# (1127, 'Whatever')
# (1128, 'When')
# (1129, 'Where')
# (1130, 'Which')
# (1131, 'While')
# (1132, 'Whitney')
# (1133, 'Whittington')
# (1134, 'Who')
# (1135, 'Whoa')
# (1136, 'Whom')
# (1137, 'Whose')
# (1138, 'Why')
# (1139, 'Wight')
# (1140, 'Wigmore')
# (1141, 'Wilhelm')
# (1142, 'Will')
# (1143, 'William')
# (1144, 'Willows')
# (1145, 'Wilson')
# (1146, 'Wilton')
# (1147, 'Wimpole')
# (1148, 'Winchester')
# (1149, 'Windibank')
# (1150, 'Windigate')
# (1151, 'With')
# (1152, 'Within')
# (1153, 'Without')
# (1154, 'Witness')
# (1155, 'Women')
# (1156, 'Won')
# (1157, 'Wood')
# (1158, 'Wooden-leg')
# (1159, 'Would')
# (1160, 'Written')
# (1161, 'X')
# (1162, 'XI')
# (1163, 'XII')
# (1164, 'Yard')
# (1165, 'Yes')
# (1166, 'Yesterday')
# (1167, 'Yet')
# (1168, 'You')
# (1169, 'Young')
# (1170, 'Your')
# (1171, 'Yours')
# (1172, 'Zealand')
# (1173, 'a')
# (1174, 'abandoned')
# (1175, 'abandons')
# (1176, 'abhorrent')
# (1177, 'abjure')
# (1178, 'able')
# (1179, 'abnormal')
# (1180, 'abnormally')
# (1181, 'abode')
# (1182, 'abominable')
# (1183, 'abomination')
# (1184, 'abound')
# (1185, 'about')
# (1186, 'above')
# (1187, 'abroad')
# (1188, 'abrupt')
# (1189, 'abruptly')
# (1190, 'absence')
# (1191, 'absent')
# (1192, 'absolute')
# (1193, 'absolutely')
# (1194, 'absolved')
# (1195, 'absorb')
# (1196, 'absorbed')
# (1197, 'absorbing')
# (1198, 'abstracted')
# (1199, 'absurd')
# (1200, 'absurdly')
# (1201, 'abuse')
# (1202, 'abusive')
# (1203, 'abutted')
# (1204, 'accent')
# (1205, 'accept')
# (1206, 'acceptance')
# (1207, 'accepted')
# (1208, 'accessory')
# (1209, 'accident')
# (1210, 'accidental')
# (1211, 'accidents')
# (1212, 'accommodate')
# (1213, 'accompanied')
# (1214, 'accompany')
# (1215, 'accompanying')
# (1216, 'accompli')
# (1217, 'accomplice')
# (1218, 'accomplish')
# (1219, 'accomplished')
# (1220, 'accomplishment')
# (1221, 'accomplishments')
# (1222, 'according')
# (1223, 'account')
# (1224, 'accountant')
# (1225, 'accounts')
# (1226, 'accumulated')
# (1227, 'accumulation')
# (1228, 'accurate')
# (1229, 'accurately')
# (1230, 'accused')
# (1231, 'accuser')
# (1232, 'accustomed')
# (1233, 'acetones')
# (1234, 'achieved')
# (1235, 'acid')
# (1236, 'acknowledge')
# (1237, 'acknowledges')
# (1238, 'acquaintance')
# (1239, 'acquiesce')
# (1240, 'acquire')
# (1241, 'acquired')
# (1242, 'acquirement')
# (1243, 'acquitted')
# (1244, 'acres')
# (1245, 'across')
# (1246, 'act')
# (1247, 'acted')
# (1248, 'acting')
# (1249, 'action')
# (1250, 'actionable')
# (1251, 'actions')
# (1252, 'active')
# (1253, 'activity')
# (1254, 'actor')
# (1255, 'actress')
# (1256, 'acts')
# (1257, 'actual')
# (1258, 'actually')
# (1259, 'acute')
# (1260, 'adapt')
# (1261, 'adapted')
# (1262, 'add')
# (1263, 'added')
# (1264, 'adder')
# (1265, 'addicted')
# (1266, 'adding')
# (1267, 'addition')
# (1268, 'address')
# (1269, 'addressed')
# (1270, 'addressing')
# (1271, 'adds')
# (1272, 'adhesive')
# (1273, 'adjective')
# (1274, 'adjusted')
# (1275, 'administration')
# (1276, 'admirable')
# (1277, 'admirably')
# (1278, 'admiration')
# (1279, 'admire')
# (1280, 'admirers')
# (1281, 'admiring')
# (1282, 'admit')
# (1283, 'admitted')
# (1284, 'ado')
# (1285, 'adopted')
# (1286, 'advance')
# (1287, 'advanced')
# (1288, 'advancing')
# (1289, 'advantage')
# (1290, 'advantages')
# (1291, 'adventure')
# (1292, 'adventures')
# (1293, 'adventuress')
# (1294, 'advertise')
# (1295, 'advertised')
# (1296, 'advertisement')
# (1297, 'advertisements')
# (1298, 'advertising')
# (1299, 'advice')
# (1300, 'advise')
# (1301, 'advised')
# (1302, 'adviser')
# (1303, 'advocate')
# (1304, 'affair')
# (1305, 'affaire')
# (1306, 'affairs')
# (1307, 'affect')
# (1308, 'affectation')
# (1309, 'affected')
# (1310, 'affecting')
# (1311, 'affection')
# (1312, 'affectionate')
# (1313, 'affections')
# (1314, 'affliction')
# (1315, 'afford')
# (1316, 'afforded')
# (1317, 'afraid')
# (1318, 'after')
# (1319, 'afternoon')
# (1320, 'afterwards')
# (1321, 'again')
# (1322, 'against')
# (1323, 'age')
# (1324, 'aged')
# (1325, 'agency')
# (1326, 'agent')
# (1327, 'agitated')
# (1328, 'agitation')
# (1329, 'ago')
# (1330, 'agonies')
# (1331, 'agony')
# (1332, 'agree')
# (1333, 'agrees')
# (1334, 'agricultural')
# (1335, 'aid')
# (1336, 'aided')
# (1337, 'air')
# (1338, 'aisle')
# (1339, 'ajar')
# (1340, 'akimbo')
# (1341, 'akin')
# (1342, 'alarm')
# (1343, 'alas')
# (1344, 'alert')
# (1345, 'alias')
# (1346, 'alike')
# (1347, 'alive')
# (1348, 'all')
# (1349, 'all-comprehensive')
# (1350, 'all-important')
# (1351, 'all-night')
# (1352, 'alleging')
# (1353, 'alley')
# (1354, 'alleys')
# (1355, 'alliance')
# (1356, 'allied')
# (1357, 'allow')
# (1358, 'allowance')
# (1359, 'allowed')
# (1360, 'allowing')
# (1361, 'allows')
# (1362, 'allude')
# (1363, 'alluded')
# (1364, 'allusion')
# (1365, 'allusions')
# (1366, 'ally')
# (1367, 'almost')
# (1368, 'alone')
# (1369, 'along')
# (1370, 'aloud')
# (1371, 'already')
# (1372, 'also')
# (1373, 'altar')
# (1374, 'alter')
# (1375, 'alterations')
# (1376, 'altered')
# (1377, 'alternately')
# (1378, 'alternating')
# (1379, 'alternation')
# (1380, 'although')
# (1381, 'altogether')
# (1382, 'always')
# (1383, 'am')
# (1384, 'amalgam')
# (1385, 'amateur')
# (1386, 'amazement')
# (1387, 'amazing')
# (1388, 'ambition')
# (1389, 'ambitious')
# (1390, 'amethyst')
# (1391, 'amiable')
# (1392, 'amid')
# (1393, 'amiss')
# (1394, 'among')
# (1395, 'amount')
# (1396, 'amplifying')
# (1397, 'amply')
# (1398, 'amuse')
# (1399, 'amused')
# (1400, 'amusement')
# (1401, 'amusing')
# (1402, 'an')
# (1403, 'analysis')
# (1404, 'analytical')
# (1405, 'anatomy')
# (1406, 'ancestral')
# (1407, 'ancient')
# (1408, 'and')
# (1409, 'anger')
# (1410, 'angle')
# (1411, 'angry')
# (1412, 'animal')
# (1413, 'animals')
# (1414, 'animated')
# (1415, 'ankles')
# (1416, 'announce')
# (1417, 'announced')
# (1418, 'announcement')
# (1419, 'annoyance')
# (1420, 'annoyed')
# (1421, 'annual')
# (1422, 'anoints')
# (1423, 'another')
# (1424, 'answer')
# (1425, 'answered')
# (1426, 'answering')
# (1427, 'answers')
# (1428, 'antagonist')
# (1429, 'antecedents')
# (1430, 'anteroom')
# (1431, 'antics')
# (1432, 'anxiety')
# (1433, 'anxious')
# (1434, 'anxiously')
# (1435, 'any')
# (1436, 'anyhow')
# (1437, 'anyone')
# (1438, 'anything')
# (1439, 'anywhere')
# (1440, 'apart')
# (1441, 'apartment')
# (1442, 'aperture')
# (1443, 'apiece')
# (1444, 'apologise')
# (1445, 'apology')
# (1446, 'apparelled')
# (1447, 'apparent')
# (1448, 'apparently')
# (1449, 'apparition')
# (1450, 'appeal')
# (1451, 'appeals')
# (1452, 'appear')
# (1453, 'appearance')
# (1454, 'appeared')
# (1455, 'appears')
# (1456, 'applicant')
# (1457, 'apply')
# (1458, 'applying')
# (1459, 'appointment')
# (1460, 'apprenticed')
# (1461, 'approach')
# (1462, 'approached')
# (1463, 'approaching')
# (1464, 'appropriate')
# (1465, 'approvingly')
# (1466, 'apt')
# (1467, 'aquiline')
# (1468, 'arc-and-compass')
# (1469, 'architects')
# (1470, 'arduous')
# (1471, 'are')
# (1472, 'area')
# (1473, 'argue')
# (1474, 'argument')
# (1475, 'arguments')
# (1476, 'aright')
# (1477, 'arise')
# (1478, 'aristocratic')
# (1479, 'arm')
# (1480, 'armchair')
# (1481, 'armchairs')
# (1482, 'armed')
# (1483, 'arms')
# (1484, 'army')
# (1485, 'around')
# (1486, 'aroused')
# (1487, 'arrange')
# (1488, 'arranged')
# (1489, 'arrangements')
# (1490, 'array')
# (1491, 'arrest')
# (1492, 'arrested')
# (1493, 'arresting')
# (1494, 'arrival')
# (1495, 'arrive')
# (1496, 'arrived')
# (1497, 'arrows')
# (1498, 'art')
# (1499, 'arteries')
# (1500, 'article')
# (1501, 'articles')
# (1502, 'artificial')
# (1503, 'artist')
# (1504, 'artistic')
# (1505, 'as')
# (1506, 'ascend')
# (1507, 'ascended')
# (1508, 'ascertain')
# (1509, 'ascertained')
# (1510, 'ascertaining')
# (1511, 'ash')
# (1512, 'ashamed')
# (1513, 'ashen')
# (1514, 'ashes')
# (1515, 'aside')
# (1516, 'ask')
# (1517, 'askance')
# (1518, 'asked')
# (1519, 'asking')
# (1520, 'asks')
# (1521, 'asleep')
# (1522, 'aspect')
# (1523, 'aspired')
# (1524, 'assailants')
# (1525, 'assault')
# (1526, 'assaulted')
# (1527, 'assembled')
# (1528, 'assert')
# (1529, 'asserted')
# (1530, 'assertion')
# (1531, 'assist')
# (1532, 'assistance')
# (1533, 'assistant')
# (1534, 'assistants')
# (1535, 'assisted')
# (1536, 'assisting')
# (1537, 'associate')
# (1538, 'associated')
# (1539, 'association')
# (1540, 'assume')
# (1541, 'assumed')
# (1542, 'assurance')
# (1543, 'assure')
# (1544, 'assured')
# (1545, 'assuredly')
# (1546, 'assures')
# (1547, 'assuring')
# (1548, 'astir')
# (1549, 'astonished')
# (1550, 'astonishment')
# (1551, 'astrakhan')
# (1552, 'astronomy')
# (1553, 'astute')
# (1554, 'astuteness')
# (1555, 'asylum')
# (1556, 'at')
# (1557, 'ate')
# (1558, 'atmosphere')
# (1559, 'atone')
# (1560, 'attached')
# (1561, 'attack')
# (1562, 'attacked')
# (1563, 'attain')
# (1564, 'attained')
# (1565, 'attainments')
# (1566, 'attempt')
# (1567, 'attempted')
# (1568, 'attempting')
# (1569, 'attempts')
# (1570, 'attend')
# (1571, 'attendant')
# (1572, 'attended')
# (1573, 'attention')
# (1574, 'attentions')
# (1575, 'attic')
# (1576, 'attics')
# (1577, 'attired')
# (1578, 'attitude')
# (1579, 'attract')
# (1580, 'attracted')
# (1581, 'attractions')
# (1582, 'audible')
# (1583, 'august')
# (1584, 'aunt')
# (1585, 'authenticity')
# (1586, 'authoritative')
# (1587, 'authorities')
# (1588, 'authority')
# (1589, 'autumn')
# (1590, 'autumnal')
# (1591, 'avail')
# (1592, 'avenue')
# (1593, 'average')
# (1594, 'averse')
# (1595, 'aversion')
# (1596, 'avert')
# (1597, 'averted')
# (1598, 'avoid')
# (1599, 'avoided')
# (1600, 'avoiding')
# (1601, 'await')
# (1602, 'awaited')
# (1603, 'awaiting')
# (1604, 'awake')
# (1605, 'awakened')
# (1606, 'aware')
# (1607, 'away')
# (1608, 'awful')
# (1609, 'awkward')
# (1610, 'awoke')
# (1611, 'axiom')
# (1612, 'ay')
# (1613, 'baboon')
# (1614, 'baby')
# (1615, 'bachelor')
# (1616, 'bachelors')
# (1617, 'back')
# (1618, 'backed')
# (1619, 'backgammon')
# (1620, 'background')
# (1621, 'backward')
# (1622, 'bad')
# (1623, 'bade')
# (1624, 'badge')
# (1625, 'badly')
# (1626, 'baffled')
# (1627, 'bag')
# (1628, 'baggy')
# (1629, 'bags')
# (1630, 'baits')
# (1631, 'balance')
# (1632, 'balanced')
# (1633, 'balancing')
# (1634, 'bald')
# (1635, 'baleful')
# (1636, 'ball')
# (1637, 'balls')
# (1638, 'balustraded')
# (1639, 'band')
# (1640, 'bandage')
# (1641, 'bandaged')
# (1642, 'bandages')
# (1643, 'bands')
# (1644, 'bandy')
# (1645, 'bang')
# (1646, 'banged')
# (1647, 'bank')
# (1648, 'banker')
# (1649, 'banking')
# (1650, 'banks')
# (1651, 'bar')
# (1652, 'barbaric')
# (1653, 'barber')
# (1654, 'bare')
# (1655, 'bargain')
# (1656, 'bark')
# (1657, 'barmaid')
# (1658, 'barometric')
# (1659, 'barque')
# (1660, 'barred')
# (1661, 'barred-tailed')
# (1662, 'barrel')
# (1663, 'barricade')
# (1664, 'barricaded')
# (1665, 'barrow')
# (1666, 'bars')
# (1667, 'baryta')
# (1668, 'base')
# (1669, 'bashful')
# (1670, 'basin')
# (1671, 'basis')
# (1672, 'basket-chair')
# (1673, 'basketful')
# (1674, 'bath')
# (1675, 'bath-sponge')
# (1676, 'bathroom')
# (1677, 'battered')
# (1678, 'battle')
# (1679, 'baying')
# (1680, 'be')
# (1681, 'beads')
# (1682, 'beam')
# (1683, 'beamed')
# (1684, 'bean')
# (1685, 'bear')
# (1686, 'beard')
# (1687, 'bearded')
# (1688, 'bearing')
# (1689, 'bearings')
# (1690, 'bears')
# (1691, 'beast')
# (1692, 'beasts')
# (1693, 'beat')
# (1694, 'beaten')
# (1695, 'beating')
# (1696, 'beauties')
# (1697, 'beautiful')
# (1698, 'beautifully')
# (1699, 'beauty')
# (1700, 'became')
# (1701, 'because')
# (1702, 'beckoned')
# (1703, 'beckoning')
# (1704, 'become')
# (1705, 'becomes')
# (1706, 'becoming')
# (1707, 'bed')
# (1708, 'bedroom')
# (1709, 'bedrooms')
# (1710, 'beds')
# (1711, 'bedside')
# (1712, 'bedtime')
# (1713, 'bee')
# (1714, 'beech')
# (1715, 'beeches')
# (1716, 'beef')
# (1717, 'been')
# (1718, 'beer')
# (1719, 'befall')
# (1720, 'befallen')
# (1721, 'before')
# (1722, 'before-breakfast')
# (1723, 'beforehand')
# (1724, 'beg')
# (1725, 'began')
# (1726, 'beget')
# (1727, 'beggar')
# (1728, 'beggarman')
# (1729, 'beggary')
# (1730, 'begged')
# (1731, 'begging')
# (1732, 'begin')
# (1733, 'beginning')
# (1734, 'beginnings')
# (1735, 'begins')
# (1736, 'begun')
# (1737, 'behind')
# (1738, 'beige')
# (1739, 'being')
# (1740, 'beings')
# (1741, 'belated')
# (1742, 'belief')
# (1743, 'believe')
# (1744, 'believed')
# (1745, 'believing')
# (1746, 'bell')
# (1747, 'bell-pull')
# (1748, 'bell-rope')
# (1749, 'bell-ropes')
# (1750, 'belonged')
# (1751, 'belonging')
# (1752, 'belongs')
# (1753, 'beloved')
# (1754, 'below')
# (1755, 'belt')
# (1756, 'bend')
# (1757, 'bending')
# (1758, 'beneath')
# (1759, 'benefactor')
# (1760, 'benevolent')
# (1761, 'bent')
# (1762, 'bequeathed')
# (1763, 'bequest')
# (1764, 'berth')
# (1765, 'berths')
# (1766, 'beryl')
# (1767, 'beryls')
# (1768, 'beside')
# (1769, 'besides')
# (1770, 'best')
# (1771, 'bet')
# (1772, 'betray')
# (1773, 'betrayed')
# (1774, 'betraying')
# (1775, 'betrothal')
# (1776, 'better')
# (1777, 'better-dressed')
# (1778, 'better-lined')
# (1779, 'between')
# (1780, 'bewilderment')
# (1781, 'beyond')
# (1782, 'biassed')
# (1783, 'bicycling')
# (1784, 'big')
# (1785, 'bigger')
# (1786, 'bijou')
# (1787, 'bile-shot')
# (1788, 'bill')
# (1789, 'billet')
# (1790, 'bills')
# (1791, 'billycock')
# (1792, 'bind')
# (1793, 'binding')
# (1794, 'biographies')
# (1795, 'biography')
# (1796, 'bird')
# (1797, 'birds')
# (1798, 'bisulphate')
# (1799, 'bit')
# (1800, 'bite')
# (1801, 'bitten')
# (1802, 'bitter')
# (1803, 'bitterly')
# (1804, 'bitterness')
# (1805, 'bizarre')
# (1806, 'black')
# (1807, 'black-haired')
# (1808, 'black-letter')
# (1809, 'blackest')
# (1810, 'blackguard')
# (1811, 'blackmailing')
# (1812, 'blacksmith')
# (1813, 'blame')
# (1814, 'blanche')
# (1815, 'blanched')
# (1816, 'bland')
# (1817, 'blandly')
# (1818, 'blasted')
# (1819, 'blaze')
# (1820, 'blazing')
# (1821, 'bleak')
# (1822, 'bled')
# (1823, 'bleeding')
# (1824, 'blend')
# (1825, 'bless')
# (1826, 'blew')
# (1827, 'blind')
# (1828, 'blinds')
# (1829, 'blinked')
# (1830, 'bloc')
# (1831, 'block')
# (1832, 'blockaded')
# (1833, 'blocked')
# (1834, 'blonde')
# (1835, 'blood')
# (1836, 'blood-stains')
# (1837, 'bloodless')
# (1838, 'bloodstains')
# (1839, 'bloody')
# (1840, 'blot')
# (1841, 'blotches')
# (1842, 'blotted')
# (1843, 'blotting-paper')
# (1844, 'blow')
# (1845, 'blowing')
# (1846, 'blown')
# (1847, 'blows')
# (1848, 'blue')
# (1849, 'blue-tinted')
# (1850, 'bluff')
# (1851, 'blundering')
# (1852, 'blunders')
# (1853, 'blunt')
# (1854, 'blur')
# (1855, 'blurs')
# (1856, 'blush')
# (1857, 'bluster')
# (1858, 'boa')
# (1859, 'board')
# (1860, 'boarding-school')
# (1861, 'boarding-schools')
# (1862, 'boards')
# (1863, 'boasting')
# (1864, 'boat')
# (1865, 'bob')
# (1866, 'bodes')
# (1867, 'bodies')
# (1868, 'body')
# (1869, 'boiling')
# (1870, 'boisterous')
# (1871, 'bold')
# (1872, 'bolted')
# (1873, 'bond')
# (1874, 'bone')
# (1875, 'bones')
# (1876, 'bonnet')
# (1877, 'bonniest')
# (1878, 'bonny')
# (1879, 'book')
# (1880, 'bookrix')
# (1881, 'books')
# (1882, 'boomed')
# (1883, 'boot')
# (1884, 'boot-lace')
# (1885, 'boot-slitting')
# (1886, 'booted')
# (1887, 'boots')
# (1888, 'border')
# (1889, 'bordered')
# (1890, 'borders')
# (1891, 'bore')
# (1892, 'bored')
# (1893, 'borne')
# (1894, 'borrow')
# (1895, 'borrowed')
# (1896, 'bosom')
# (1897, 'both')
# (1898, 'bottle')
# (1899, 'bottles')
# (1900, 'bottom')
# (1901, 'bought')
# (1902, 'bound')
# (1903, 'boundary')
# (1904, 'bounded')
# (1905, 'bounds')
# (1906, 'bouquet')
# (1907, 'bow')
# (1908, 'bow-window')
# (1909, 'bowed')
# (1910, 'bowing')
# (1911, 'bowls')
# (1912, 'box')
# (1913, 'box-room')
# (1914, 'boxed')
# (1915, 'boxer')
# (1916, 'boxes')
# (1917, 'boy')
# (1918, 'boyish')
# (1919, 'boys')
# (1920, 'brace')
# (1921, 'braced')
# (1922, 'bracelets')
# (1923, 'brain')
# (1924, 'brain-attic')
# (1925, 'brain-fever')
# (1926, 'brains')
# (1927, 'bramble-covered')
# (1928, 'branch')
# (1929, 'branches')
# (1930, 'branded')
# (1931, 'brandy')
# (1932, 'brass')
# (1933, 'brassy')
# (1934, 'brave')
# (1935, 'braved')
# (1936, 'braving')
# (1937, 'brawls')
# (1938, 'brazen')
# (1939, 'brazier')
# (1940, 'breach')
# (1941, 'breaches')
# (1942, 'bread')
# (1943, 'breadth')
# (1944, 'break')
# (1945, 'breakfast')
# (1946, 'breakfast-room')
# (1947, 'breakfast-table')
# (1948, 'breakfasts')
# (1949, 'breaking')
# (1950, 'breaks')
# (1951, 'breast')
# (1952, 'breastpin')
# (1953, 'breath')
# (1954, 'breathe')
# (1955, 'breathed')
# (1956, 'breathing')
# (1957, 'breathlessly')
# (1958, 'bred')
# (1959, 'brewer')
# (1960, 'briar')
# (1961, 'brick')
# (1962, 'brickish')
# (1963, 'bricks')
# (1964, 'bridal')
# (1965, 'bride')
# (1966, 'bridegroom')
# (1967, 'bridge')
# (1968, 'brief')
# (1969, 'briefly')
# (1970, 'bright')
# (1971, 'bright-looking')
# (1972, 'brighter')
# (1973, 'brightest')
# (1974, 'brightly')
# (1975, 'brightness')
# (1976, 'brilliant')
# (1977, 'brilliantly')
# (1978, 'brim')
# (1979, 'brims')
# (1980, 'bring')
# (1981, 'bringing')
# (1982, 'brings')
# (1983, 'brisk')
# (1984, 'briskly')
# (1985, 'broad')
# (1986, 'broad-brimmed')
# (1987, 'broadened')
# (1988, 'broader')
# (1989, 'broadest')
# (1990, 'broke')
# (1991, 'broken')
# (1992, 'brooch')
# (1993, 'brother')
# (1994, 'brothers')
# (1995, 'brougham')
# (1996, 'brought')
# (1997, 'brow')
# (1998, 'brown')
# (1999, 'brownish')
# (2000, 'brows')
# (2001, 'bruise')
# (2002, 'brushed')
# (2003, 'brute')
# (2004, 'buckles')
# (2005, 'budge')
# (2006, 'buffalo')
# (2007, 'build')
# (2008, 'builder')
# (2009, 'building')
# (2010, 'buildings')
# (2011, 'built')
# (2012, 'bulge')
# (2013, 'bulky')
# (2014, 'bulldog')
# (2015, 'bullet')
# (2016, 'bullion')
# (2017, 'bumping')
# (2018, 'bunch')
# (2019, 'bundle')
# (2020, 'bundles')
# (2021, 'burden')
# (2022, 'bureau')
# (2023, 'burglar')
# (2024, 'burglars')
# (2025, 'burgled')
# (2026, 'buried')
# (2027, 'burly')
# (2028, 'burned')
# (2029, 'burning')
# (2030, 'burnished')
# (2031, 'burrowing')
# (2032, 'burst')
# (2033, 'bush')
# (2034, 'bushes')
# (2035, 'bushy')
# (2036, 'busier')
# (2037, 'business')
# (2038, 'businesslike')
# (2039, 'bustled')
# (2040, 'bustling')
# (2041, 'busy')
# (2042, 'busybody')
# (2043, 'but')
# (2044, 'butcher')
# (2045, 'butler')
# (2046, 'butt-end')
# (2047, 'butted')
# (2048, 'buttoned')
# (2049, 'buttoning')
# (2050, 'buttons')
# (2051, 'buy')
# (2052, 'buying')
# (2053, 'buzz')
# (2054, 'buzzing')
# (2055, 'by')
# (2056, 'c')
# (2057, 'cab')
# (2058, 'cabby')
# (2059, 'cabinet')
# (2060, 'cable')
# (2061, 'cabman')
# (2062, 'cabs')
# (2063, 'cadaverous')
# (2064, 'cage')
# (2065, 'caged')
# (2066, 'cake')
# (2067, 'calamity')
# (2068, 'calf')
# (2069, 'call')
# (2070, 'called')
# (2071, 'calling')
# (2072, 'calls')
# (2073, 'calmly')
# (2074, 'caltrops')
# (2075, 'calves')
# (2076, 'came')
# (2077, 'camera')
# (2078, 'camp')
# (2079, 'camp-bed')
# (2080, 'campaign')
# (2081, 'campaigner')
# (2082, 'can')
# (2083, 'candid')
# (2084, 'candidate')
# (2085, 'candle')
# (2086, 'cane')
# (2087, 'cannot')
# (2088, 'canvas')
# (2089, 'cap')
# (2090, 'capable')
# (2091, 'capacity')
# (2092, 'capital')
# (2093, 'caps')
# (2094, 'capture')
# (2095, 'captured')
# (2096, 'caraffe')
# (2097, 'carbolised')
# (2098, 'carbuncle')
# (2099, 'card')
# (2100, 'card-case')
# (2101, 'cardboard')
# (2102, 'cards')
# (2103, 'care')
# (2104, 'cared')
# (2105, 'career')
# (2106, 'careful')
# (2107, 'carefully')
# (2108, 'careless')
# (2109, 'carelessly')
# (2110, 'cares')
# (2111, 'caress')
# (2112, 'caressing')
# (2113, 'cargo')
# (2114, 'carpenter')
# (2115, 'carpet')
# (2116, 'carpet-bag')
# (2117, 'carpets')
# (2118, 'carriage')
# (2119, 'carriage-building')
# (2120, 'carriage-sweep')
# (2121, 'carried')
# (2122, 'carries')
# (2123, 'carry')
# (2124, 'carrying')
# (2125, 'carrée')
# (2126, 'cart')
# (2127, 'carte')
# (2128, 'carts')
# (2129, 'carved')
# (2130, 'cascade')
# (2131, 'case')
# (2132, 'case-book')
# (2133, 'caseful')
# (2134, 'cases')
# (2135, 'cashbox')
# (2136, 'cashier')
# (2137, 'casket')
# (2138, 'cast')
# (2139, 'cast-off')
# (2140, 'casting')
# (2141, 'cat')
# (2142, 'catastrophe')
# (2143, 'catch')
# (2144, 'catching')
# (2145, 'category')
# (2146, 'cathedral')
# (2147, 'catlike')
# (2148, 'caught')
# (2149, 'cause')
# (2150, 'caused')
# (2151, 'causes')
# (2152, 'causing')
# (2153, 'caution')
# (2154, 'cave')
# (2155, 'caved')
# (2156, 'cease')
# (2157, 'ceased')
# (2158, 'ceaseless')
# (2159, 'ceases')
# (2160, 'ceiling')
# (2161, 'celebrated')
# (2162, 'cell')
# (2163, 'cellar')
# (2164, 'cells')
# (2165, 'cent')
# (2166, 'central')
# (2167, 'centre')
# (2168, 'centuries')
# (2169, 'century')
# (2170, 'ceremony')
# (2171, 'certain')
# (2172, 'certainly')
# (2173, 'certainty')
# (2174, 'certificates')
# (2175, 'chaff')
# (2176, 'chaffed')
# (2177, 'chaffering')
# (2178, 'chagrin')
# (2179, 'chagrined')
# (2180, 'chain')
# (2181, 'chains')
# (2182, 'chair')
# (2183, 'chairman')
# (2184, 'chairs')
# (2185, 'chalk')
# (2186, 'chalk-pit')
# (2187, 'chalk-pits')
# (2188, 'chamber')
# (2189, 'chambers')
# (2190, 'chamois')
# (2191, 'chance')
# (2192, 'chanced')
# (2193, 'chances')
# (2194, 'change')
# (2195, 'changed')
# (2196, 'changes')
# (2197, 'changing')
# (2198, 'chap')
# (2199, 'chapter')
# (2200, 'character')
# (2201, 'characterises')
# (2202, 'characteristic')
# (2203, 'characteristics')
# (2204, 'characters')
# (2205, 'charcoal')
# (2206, 'charge')
# (2207, 'charged')
# (2208, 'charity')
# (2209, 'charm')
# (2210, 'charming')
# (2211, 'charred')
# (2212, 'chase')
# (2213, 'chased')
# (2214, 'chasing')
# (2215, 'chat')
# (2216, 'chatted')
# (2217, 'chatting')
# (2218, 'cheap')
# (2219, 'cheating')
# (2220, 'check')
# (2221, 'check-book')
# (2222, 'checkmate')
# (2223, 'cheekbones')
# (2224, 'cheeks')
# (2225, 'cheer')
# (2226, 'cheerful')
# (2227, 'cheerily')
# (2228, 'cheerless')
# (2229, 'cheery')
# (2230, 'cheetah')
# (2231, 'chemical')
# (2232, 'chemistry')
# (2233, 'cherry-wood')
# (2234, 'chest')
# (2235, 'chestnut')
# (2236, 'chewing')
# (2237, 'chief')
# (2238, 'chiffon')
# (2239, 'child')
# (2240, 'childish')
# (2241, 'children')
# (2242, 'chill')
# (2243, 'chimney')
# (2244, 'chimneys')
# (2245, 'chin')
# (2246, 'china')
# (2247, 'chinchilla')
# (2248, 'chink')
# (2249, 'chins')
# (2250, 'chisel')
# (2251, 'chivalrous')
# (2252, 'choked')
# (2253, 'choose')
# (2254, 'choosing')
# (2255, 'chose')
# (2256, 'chosen')
# (2257, 'chronic')
# (2258, 'chronicle')
# (2259, 'chronicler')
# (2260, 'chucked')
# (2261, 'chuckled')
# (2262, 'chuckling')
# (2263, 'church')
# (2264, 'cigar')
# (2265, 'cigar-')
# (2266, 'cigar-holder')
# (2267, 'cigarette')
# (2268, 'cigarettes')
# (2269, 'cigars')
# (2270, 'cinder')
# (2271, 'circle')
# (2272, 'circles')
# (2273, 'circulation')
# (2274, 'circumspect')
# (2275, 'circumstances')
# (2276, 'circumstantial')
# (2277, 'citizens')
# (2278, 'city')
# (2279, 'civil')
# (2280, 'civilisation')
# (2281, 'civilised')
# (2282, 'clad')
# (2283, 'claim')
# (2284, 'claim-jumping')
# (2285, 'clambered')
# (2286, 'clamped')
# (2287, 'clang')
# (2288, 'clanging')
# (2289, 'clank')
# (2290, 'clanking')
# (2291, 'clapped')
# (2292, 'claret')
# (2293, 'clasped')
# (2294, 'clasping')
# (2295, 'claspings')
# (2296, 'class')
# (2297, 'classes')
# (2298, 'clatter')
# (2299, 'clattered')
# (2300, 'claws')
# (2301, 'clay')
# (2302, 'clean')
# (2303, 'clean-cut')
# (2304, 'clean-shaven')
# (2305, 'cleaned')
# (2306, 'cleanly')
# (2307, 'clear')
# (2308, 'cleared')
# (2309, 'clearer')
# (2310, 'clearing')
# (2311, 'clearly')
# (2312, 'clears')
# (2313, 'cleaver')
# (2314, 'clenched')
# (2315, 'clergyman')
# (2316, 'clerk')
# (2317, 'clerks')
# (2318, 'clever')
# (2319, 'cleverness')
# (2320, 'client')
# (2321, 'clients')
# (2322, 'climate')
# (2323, 'climbed')
# (2324, 'climbing')
# (2325, 'clinched')
# (2326, 'clink')
# (2327, 'clinked')
# (2328, 'cloak')
# (2329, 'clock')
# (2330, 'close')
# (2331, 'close-fitting')
# (2332, 'closed')
# (2333, 'closely')
# (2334, 'closing')
# (2335, 'cloth')
# (2336, 'clothes')
# (2337, 'cloud')
# (2338, 'cloud-wreaths')
# (2339, 'clouded')
# (2340, 'cloudless')
# (2341, 'clouds')
# (2342, 'club')
# (2343, 'clue')
# (2344, 'clues')
# (2345, 'clump')
# (2346, 'clumps')
# (2347, 'clumsy')
# (2348, 'cluster')
# (2349, 'clutched')
# (2350, 'clutches')
# (2351, 'clutching')
# (2352, 'co-operation')
# (2353, 'coach-house')
# (2354, 'coachman')
# (2355, 'coarse')
# (2356, 'coarsely')
# (2357, 'coat')
# (2358, 'coat-sleeve')
# (2359, 'coat-tails')
# (2360, 'coaxing')
# (2361, 'cobbler')
# (2362, 'cobwebby')
# (2363, 'cocaine')
# (2364, 'cock-and-bull')
# (2365, 'cocked')
# (2366, 'cocking')
# (2367, 'cockroaches')
# (2368, 'cocksure')
# (2369, 'cocktail')
# (2370, 'coeur')
# (2371, 'coffee')
# (2372, 'coil')
# (2373, 'coin')
# (2374, 'coincidence')
# (2375, 'coincidences')
# (2376, 'coincident')
# (2377, 'coiners')
# (2378, 'coins')
# (2379, 'cold')
# (2380, 'cold-blooded')
# (2381, 'coldly')
# (2382, 'coldness')
# (2383, 'collapse')
# (2384, 'collapsed')
# (2385, 'collar')
# (2386, 'colleague')
# (2387, 'collected')
# (2388, 'collecting')
# (2389, 'collection')
# (2390, 'college')
# (2391, 'colonel')
# (2392, 'colonies')
# (2393, 'colony')
# (2394, 'colour')
# (2395, 'coloured')
# (2396, 'colourless')
# (2397, 'column')
# (2398, 'columns')
# (2399, 'com/-gunnar')
# (2400, 'combination')
# (2401, 'combinations')
# (2402, 'combine')
# (2403, 'combined')
# (2404, 'come')
# (2405, 'comely')
# (2406, 'comes')
# (2407, 'comfort')
# (2408, 'comfortable')
# (2409, 'comfortable-looking')
# (2410, 'comfortably')
# (2411, 'comforted')
# (2412, 'comic')
# (2413, 'comical')
# (2414, 'coming')
# (2415, 'command')
# (2416, 'commanding')
# (2417, 'commands')
# (2418, 'commence')
# (2419, 'commencement')
# (2420, 'comment')
# (2421, 'commenting')
# (2422, 'commerce')
# (2423, 'commission')
# (2424, 'commissionaire')
# (2425, 'commissions')
# (2426, 'commit')
# (2427, 'committed')
# (2428, 'common')
# (2429, 'common-looking')
# (2430, 'commonly')
# (2431, 'commonplace')
# (2432, 'commonplaces')
# (2433, 'communicate')
# (2434, 'communicated')
# (2435, 'communication')
# (2436, 'communicative')
# (2437, 'community')
# (2438, 'commuting')
# (2439, 'companies')
# (2440, 'companion')
# (2441, 'companions')
# (2442, 'company')
# (2443, 'comparatively')
# (2444, 'compared')
# (2445, 'comparing')
# (2446, 'compass')
# (2447, 'compasses')
# (2448, 'compelled')
# (2449, 'compensated')
# (2450, 'competence')
# (2451, 'competition')
# (2452, 'complain')
# (2453, 'complained')
# (2454, 'complaint')
# (2455, 'complete')
# (2456, 'completed')
# (2457, 'completely')
# (2458, 'complex')
# (2459, 'complexion')
# (2460, 'compliance')
# (2461, 'complicates')
# (2462, 'compliment')
# (2463, 'complimentary')
# (2464, 'complimented')
# (2465, 'compliments')
# (2466, 'comply')
# (2467, 'compose')
# (2468, 'composed')
# (2469, 'composer')
# (2470, 'compositor')
# (2471, 'compress')
# (2472, 'compressed')
# (2473, 'compromise')
# (2474, 'compromised')
# (2475, 'compromising')
# (2476, 'compunction')
# (2477, 'comrade')
# (2478, 'conceal')
# (2479, 'concealed')
# (2480, 'concealment')
# (2481, 'conceit')
# (2482, 'conceivable')
# (2483, 'conceive')
# (2484, 'conceives')
# (2485, 'concentrate')
# (2486, 'concentrated')
# (2487, 'concentration')
# (2488, 'conception')
# (2489, 'concern')
# (2490, 'concerned')
# (2491, 'concerning')
# (2492, 'concert')
# (2493, 'concerts')
# (2494, 'concise')
# (2495, 'concisely')
# (2496, 'concluded')
# (2497, 'concluding')
# (2498, 'conclusion')
# (2499, 'conclusions')
# (2500, 'conclusive')
# (2501, 'condemned')
# (2502, 'condescend')
# (2503, 'condition')
# (2504, 'conditions')
# (2505, 'conduct')
# (2506, 'conducted')
# (2507, 'conducting')
# (2508, 'confectioner')
# (2509, 'confederate')
# (2510, 'confederates')
# (2511, 'confess')
# (2512, 'confessed')
# (2513, 'confession')
# (2514, 'confidant')
# (2515, 'confide')
# (2516, 'confided')
# (2517, 'confidence')
# (2518, 'confidential')
# (2519, 'confine')
# (2520, 'confined')
# (2521, 'confining')
# (2522, 'confirm')
# (2523, 'confirmed')
# (2524, 'confound')
# (2525, 'confronted')
# (2526, 'confused')
# (2527, 'confusion')
# (2528, 'congenial')
# (2529, 'congratulate')
# (2530, 'congratulated')
# (2531, 'conjecture')
# (2532, 'conjectured')
# (2533, 'conjunction')
# (2534, 'connected')
# (2535, 'connection')
# (2536, 'connivance')
# (2537, 'conscience')
# (2538, 'conscious')
# (2539, 'consciousness')
# (2540, 'consented')
# (2541, 'consequence')
# (2542, 'consequences')
# (2543, 'consequential')
# (2544, 'consider')
# (2545, 'considerable')
# (2546, 'considerably')
# (2547, 'consideration')
# (2548, 'considerations')
# (2549, 'considered')
# (2550, 'considering')
# (2551, 'consisted')
# (2552, 'consoled')
# (2553, 'conspicuous')
# (2554, 'conspiring')
# (2555, 'constable')
# (2556, 'constables')
# (2557, 'constabulary')
# (2558, 'consternation')
# (2559, 'constitution')
# (2560, 'constraint')
# (2561, 'constructed')
# (2562, 'construction')
# (2563, 'consult')
# (2564, 'consultations')
# (2565, 'consulted')
# (2566, 'consulting')
# (2567, 'consulting-room')
# (2568, 'consults')
# (2569, 'consumed')
# (2570, 'consuming')
# (2571, 'contact')
# (2572, 'contain')
# (2573, 'contained')
# (2574, 'containing')
# (2575, 'contains')
# (2576, 'contemplation')
# (2577, 'contemplative')
# (2578, 'contemptuous')
# (2579, 'contents')
# (2580, 'continents')
# (2581, 'continually')
# (2582, 'continue')
# (2583, 'continued')
# (2584, 'continues')
# (2585, 'continuously')
# (2586, 'contortions')
# (2587, 'contraction')
# (2588, 'contradict')
# (2589, 'contrary')
# (2590, 'contrast')
# (2591, 'contributed')
# (2592, 'contrition')
# (2593, 'control')
# (2594, 'controlled')
# (2595, 'conundrums')
# (2596, 'convenience')
# (2597, 'convenient')
# (2598, 'conveniently')
# (2599, 'conventionalities')
# (2600, 'conventions')
# (2601, 'conversation')
# (2602, 'converse')
# (2603, 'conveyed')
# (2604, 'conviction')
# (2605, 'convince')
# (2606, 'convinced')
# (2607, 'convincing')
# (2608, 'convoy')
# (2609, 'convulse')
# (2610, 'convulsed')
# (2611, 'convulsion')
# (2612, 'convulsive')
# (2613, 'cooking')
# (2614, 'cool')
# (2615, 'coolest')
# (2616, 'coolness')
# (2617, 'cooped')
# (2618, 'copier')
# (2619, 'copper')
# (2620, 'coppers')
# (2621, 'copy')
# (2622, 'copying')
# (2623, 'coquettish')
# (2624, 'cord')
# (2625, 'cordially')
# (2626, 'corner')
# (2627, 'corners')
# (2628, 'coroner')
# (2629, 'coronet')
# (2630, 'correct')
# (2631, 'correctly')
# (2632, 'corresponded')
# (2633, 'correspondence')
# (2634, 'correspondent')
# (2635, 'corresponds')
# (2636, 'corridor')
# (2637, 'corridor-lamp')
# (2638, 'corridors')
# (2639, 'corroborate')
# (2640, 'corroboration')
# (2641, 'cost')
# (2642, 'coster')
# (2643, 'costume')
# (2644, 'cosy')
# (2645, 'cotton')
# (2646, 'couch')
# (2647, 'cough')
# (2648, 'could')
# (2649, 'couldn')
# (2650, 'counsel')
# (2651, 'counsellor')
# (2652, 'count')
# (2653, 'counties')
# (2654, 'country')
# (2655, 'country-house')
# (2656, 'country-houses')
# (2657, 'country-side')
# (2658, 'country-town')
# (2659, 'countryside')
# (2660, 'counts')
# (2661, 'county')
# (2662, 'couple')
# (2663, 'coupled')
# (2664, 'couples')
# (2665, 'courage')
# (2666, 'course')
# (2667, 'court')
# (2668, 'court-yard')
# (2669, 'courtesy')
# (2670, 'cousin')
# (2671, 'cousins')
# (2672, 'cover')
# (2673, 'covered')
# (2674, 'crab')
# (2675, 'crack')
# (2676, 'cracked')
# (2677, 'crackling')
# (2678, 'cracks')
# (2679, 'craggy')
# (2680, 'crash')
# (2681, 'crate')
# (2682, 'crates')
# (2683, 'cravat')
# (2684, 'cravats')
# (2685, 'crawl')
# (2686, 'crawled')
# (2687, 'creaking')
# (2688, 'creases')
# (2689, 'creature')
# (2690, 'creatures')
# (2691, 'credit')
# (2692, 'creditable')
# (2693, 'creditor')
# (2694, 'creeping')
# (2695, 'crest')
# (2696, 'crib')
# (2697, 'cried')
# (2698, 'cries')
# (2699, 'crime')
# (2700, 'crimes')
# (2701, 'criminal')
# (2702, 'criminals')
# (2703, 'cringe')
# (2704, 'cringing')
# (2705, 'crinkled')
# (2706, 'cripple')
# (2707, 'crippled')
# (2708, 'crisis')
# (2709, 'crisp')
# (2710, 'crisply')
# (2711, 'crocuses')
# (2712, 'crony')
# (2713, 'crop')
# (2714, 'cross')
# (2715, 'cross-indexing')
# (2716, 'cross-legged')
# (2717, 'cross-purposes')
# (2718, 'cross-questioning')
# (2719, 'crossed')
# (2720, 'crouched')
# (2721, 'crowd')
# (2722, 'crowded')
# (2723, 'crown')
# (2724, 'crucial')
# (2725, 'crude')
# (2726, 'crudest')
# (2727, 'cruel')
# (2728, 'cruelly')
# (2729, 'cruelty')
# (2730, 'crumbly')
# (2731, 'crumpled')
# (2732, 'crushed')
# (2733, 'crushing')
# (2734, 'crust')
# (2735, 'crusted')
# (2736, 'cry')
# (2737, 'crying')
# (2738, 'crystallised')
# (2739, 'crystals')
# (2740, 'cub')
# (2741, 'cubic')
# (2742, 'cudgelled')
# ...
# (7824, 'there')
# (7825, 'thereby')
# (7826, 'therefore')
# (7827, 'these')
# (7828, 'they')
# (7829, 'thick')
# (7830, 'thick-soled')
# (7831, 'thickening')
# (7832, 'thicket')
# (7833, 'thickly')
# (7834, 'thickness')
# (7835, 'thief')
# (7836, 'thieves')
# (7837, 'thin')
# (7838, 'thing')
# (7839, 'things')
# (7840, 'think')
# (7841, 'thinker')
# (7842, 'thinking')
# (7843, 'thinks')
# (7844, 'thinness')
# (7845, 'third')
# (7846, 'thirty')
# (7847, 'thirty-nine')
# (7848, 'thirty-seven')
# (7849, 'thirty-six')
# (7850, 'this')
# (7851, 'thither')
# (7852, 'thoroughfare')
# (7853, 'thoroughly')
# (7854, 'those')
# (7855, 'though')
# (7856, 'thought')
# (7857, 'thoughtful')
# (7858, 'thoughtfully')
# (7859, 'thoughtless')
# (7860, 'thoughts')
# (7861, 'thousand')
# (7862, 'thousands')
# (7863, 'thread')
# (7864, 'threat')
# (7865, 'threaten')
# (7866, 'threatened')
# (7867, 'threatening')
# (7868, 'threatens')
# (7869, 'threats')
# (7870, 'three')
# (7871, 'three-legged')
# (7872, 'threshold')
# (7873, 'thresholds')
# (7874, 'threw')
# (7875, 'thrill')
# (7876, 'thrilling')
# (7877, 'throat')
# (7878, 'throats')
# (7879, 'throbbed')
# (7880, 'throbbing')
# (7881, 'through')
# (7882, 'throughout')
# (7883, 'throw')
# (7884, 'throwing')
# (7885, 'thrown')
# (7886, 'throws')
# (7887, 'thrust')
# (7888, 'thrusting')
# (7889, 'thud')
# (7890, 'thudding')
# (7891, 'thumb')
# (7892, 'thumb-nails')
# (7893, 'thumped')
# (7894, 'thus')
# (7895, 'tiara')
# (7896, 'ticket')
# (7897, 'tickets')
# (7898, 'ticking')
# (7899, 'tide')
# (7900, 'tide-waiter')
# (7901, 'tidy')
# (7902, 'tie')
# (7903, 'tied')
# (7904, 'tiger')
# (7905, 'tight')
# (7906, 'tightly')
# (7907, 'till')
# (7908, 'tilted')
# (7909, 'timbered')
# (7910, 'time')
# (7911, 'times')
# (7912, 'timid')
# (7913, 'tin')
# (7914, 'tinge')
# (7915, 'tinged')
# (7916, 'tiniest')
# (7917, 'tinker')
# (7918, 'tint')
# (7919, 'tinted')
# (7920, 'tiny')
# (7921, 'tip')
# (7922, 'tiptoes')
# (7923, 'tire')
# (7924, 'tired')
# (7925, 'tissue')
# (7926, 'title')
# (7927, 'to')
# (7928, 'to-day')
# (7929, 'to-morrow')
# (7930, 'to-night')
# (7931, 'toast')
# (7932, 'tobacco')
# (7933, 'tobacconist')
# (7934, 'toe')
# (7935, 'toe-cap')
# (7936, 'together')
# (7937, 'token')
# (7938, 'told')
# (7939, 'tomboy')
# (7940, 'tomfoolery')
# (7941, 'tomorrow')
# (7942, 'tone')
# (7943, 'tones')
# (7944, 'tongs')
# (7945, 'tongue')
# (7946, 'tonnage')
# (7947, 'tons')
# (7948, 'too')
# (7949, 'took')
# (7950, 'tool')
# (7951, 'tools')
# (7952, 'tooth')
# (7953, 'tooth-brush')
# (7954, 'top')
# (7955, 'top-hat')
# (7956, 'topic')
# (7957, 'topped')
# (7958, 'tops')
# (7959, 'tore')
# (7960, 'torn')
# (7961, 'tortured')
# (7962, 'tossed')
# (7963, 'tossing')
# (7964, 'total')
# (7965, 'touch')
# (7966, 'touched')
# (7967, 'touching')
# (7968, 'tout')
# (7969, 'towards')
# (7970, 'tower')
# (7971, 'town')
# (7972, 'towns')
# (7973, 'toy')
# (7974, 'trace')
# (7975, 'traced')
# (7976, 'traces')
# (7977, 'track')
# (7978, 'tracks')
# (7979, 'trade')
# (7980, 'trade-mark')
# (7981, 'tradesman')
# (7982, 'tradesmen')
# (7983, 'tradespeople')
# (7984, 'traditions')
# (7985, 'traffic')
# (7986, 'tragedy')
# (7987, 'tragic')
# (7988, 'trail')
# (7989, 'train')
# (7990, 'trained')
# (7991, 'training')
# (7992, 'trains')
# (7993, 'tramped')
# (7994, 'trampled')
# (7995, 'transaction')
# (7996, 'transferred')
# (7997, 'transform')
# (7998, 'transformed')
# (7999, 'transformer')
# (8000, 'transition')
# (8001, 'transmit')
# (8002, 'transparent')
# (8003, 'transpired')
# (8004, 'transverse')
# (8005, 'trap')
# (8006, 'trap-door')
# (8007, 'travel')
# (8008, 'travelled')
# (8009, 'traveller')
# (8010, 'travellers')
# (8011, 'travelling')
# (8012, 'travelling-cloak')
# (8013, 'travels')
# (8014, 'tray')
# (8015, 'treachery')
# (8016, 'tread')
# (8017, 'treasure')
# (8018, 'treat')
# (8019, 'treated')
# (8020, 'treatises')
# (8021, 'treble')
# (8022, 'tree')
# (8023, 'trees')
# (8024, 'trembling')
# (8025, 'tremor')
# (8026, 'trespasser')
# (8027, 'tresses')
# (8028, 'trials')
# (8029, 'triangular')
# (8030, 'trick')
# (8031, 'tricked')
# (8032, 'tricks')
# (8033, 'tricky')
# (8034, 'tried')
# (8035, 'trifle')
# (8036, 'trifles')
# (8037, 'trifling')
# (8038, 'trim')
# (8039, 'trimly')
# (8040, 'trimmed')
# (8041, 'trip')
# (8042, 'trite')
# (8043, 'triumph')
# (8044, 'triumphant')
# (8045, 'trivial')
# (8046, 'trooped')
# (8047, 'troopers')
# (8048, 'trophy')
# (8049, 'tropics')
# (8050, 'trouble')
# (8051, 'troubled')
# (8052, 'troubles')
# (8053, 'troubling')
# (8054, 'trough')
# (8055, 'trouser')
# (8056, 'trousers')
# (8057, 'trout')
# (8058, 'trove')
# (8059, 'true')
# (8060, 'truly')
# (8061, 'trumpet')
# (8062, 'trunk')
# (8063, 'trunks')
# (8064, 'trust')
# (8065, 'trusted')
# (8066, 'trustees')
# (8067, 'trusty')
# (8068, 'truth')
# (8069, 'try')
# (8070, 'trying')
# (8071, 'tucked')
# (8072, 'tug')
# (8073, 'tugged')
# (8074, 'tugging')
# (8075, 'tumbled')
# (8076, 'tumbler')
# (8077, 'tumultuously')
# (8078, 'tune')
# (8079, 'tunes')
# (8080, 'tunnel')
# (8081, 'tunnels')
# (8082, 'turf')
# (8083, 'turn')
# (8084, 'turned')
# (8085, 'turning')
# (8086, 'turns')
# (8087, 'tut')
# (8088, 'tweed')
# (8089, 'tweed-suited')
# (8090, 'twelve')
# (8091, 'twelve-mile')
# (8092, 'twentieth')
# (8093, 'twenty')
# (8094, 'twenty-five')
# (8095, 'twenty-one')
# (8096, 'twenty-seven')
# (8097, 'twenty-six')
# (8098, 'twice')
# (8099, 'twig')
# (8100, 'twilight')
# (8101, 'twinkle')
# (8102, 'twinkled')
# (8103, 'twinkling')
# (8104, 'twins')
# (8105, 'twist')
# (8106, 'twisted')
# (8107, 'twitch')
# (8108, 'twitching')
# (8109, 'twitter')
# (8110, 'two')
# (8111, 'two-and-twenty')
# (8112, 'two-edged')
# (8113, 'two-hundred-year-old')
# (8114, 'two-storied')
# (8115, 'twopence')
# (8116, 'tying')
# (8117, 'type')
# (8118, 'typewrite')
# (8119, 'typewriter')
# (8120, 'typewriting')
# (8121, 'typewritist')
# (8122, 'typewritten')
# (8123, 'ugliness')
# (8124, 'ugly')
# (8125, 'ulster')
# (8126, 'ulsters')
# (8127, 'ultimate')
# (8128, 'umbrella')
# (8129, 'un')
# (8130, 'unable')
# (8131, 'unacquainted')
# (8132, 'unapproachable')
# (8133, 'unavenged')
# (8134, 'unbreakable')
# (8135, 'unburned')
# (8136, 'unbuttoned')
# (8137, 'uncarpeted')
# (8138, 'uncertain')
# (8139, 'unclasping')
# (8140, 'unclaspings')
# (8141, 'uncle')
# (8142, 'uncomfortable')
# (8143, 'uncommon')
# (8144, 'uncompromising')
# (8145, 'unconcerned')
# (8146, 'uncongenial')
# (8147, 'unconscious')
# (8148, 'uncontrollable')
# (8149, 'uncourteous')
# (8150, 'uncouth')
# (8151, 'uncovered')
# (8152, 'undated')
# (8153, 'under')
# (8154, 'undergo')
# (8155, 'underneath')
# (8156, 'understand')
# (8157, 'understanding')
# (8158, 'understood')
# (8159, 'undertake')
# (8160, 'undertaking')
# (8161, 'undid')
# (8162, 'undo')
# (8163, 'undoing')
# (8164, 'undoubtedly')
# (8165, 'undue')
# (8166, 'uneasiness')
# (8167, 'uneasy')
# (8168, 'unexpected')
# (8169, 'unfailingly')
# (8170, 'unfeigned')
# (8171, 'unfenced')
# (8172, 'unfettered')
# (8173, 'unfinished')
# (8174, 'unforeseen')
# (8175, 'unfortunate')
# (8176, 'unfortunately')
# (8177, 'ungenerously')
# (8178, 'ungovernable')
# (8179, 'ungrateful')
# (8180, 'unhappy')
# (8181, 'unhealthy')
# (8182, 'unheeded')
# (8183, 'uniform')
# (8184, 'unimpeachable')
# (8185, 'unimportant')
# (8186, 'union')
# (8187, 'unique')
# (8188, 'united')
# (8189, 'unkempt')
# (8190, 'unknown')
# (8191, 'unless')
# (8192, 'unlike')
# (8193, 'unlikely')
# (8194, 'unlocked')
# (8195, 'unlocking')
# (8196, 'unmarried')
# (8197, 'unmistakable')
# (8198, 'unnatural')
# (8199, 'unnecessary')
# (8200, 'unnoticed')
# (8201, 'unobservant')
# (8202, 'unobserved')
# (8203, 'unofficial')
# (8204, 'unopened')
# (8205, 'unpack')
# (8206, 'unpacked')
# (8207, 'unpapered')
# (8208, 'unpleasant')
# (8209, 'unpleasantness')
# (8210, 'unprecedented')
# (8211, 'unprofitable')
# (8212, 'unravel')
# (8213, 'unravelled')
# (8214, 'unravelling')
# (8215, 'unreasoning')
# (8216, 'unrepaired')
# (8217, 'unseat')
# (8218, 'unsolved')
# (8219, 'unsystematic')
# (8220, 'untamed')
# (8221, 'unthinkable')
# (8222, 'until')
# (8223, 'untimely')
# (8224, 'unusual')
# (8225, 'unusually')
# (8226, 'unwelcome')
# (8227, 'unwise')
# (8228, 'unwound')
# (8229, 'up')
# (8230, 'upbraided')
# (8231, 'upon')
# (8232, 'upper')
# (8233, 'upper-attendant')
# (8234, 'uppermost')
# (8235, 'upraised')
# (8236, 'uproar')
# (8237, 'upset')
# (8238, 'upstairs')
# (8239, 'upward')
# (8240, 'urged')
# (8241, 'urgency')
# (8242, 'urgent')
# (8243, 'urging')
# (8244, 'us')
# (8245, 'use')
# (8246, 'used')
# (8247, 'useful')
# (8248, 'useless')
# (8249, 'uses')
# (8250, 'ushered')
# (8251, 'ushering')
# (8252, 'using')
# (8253, 'usual')
# (8254, 'usually')
# (8255, 'utilise')
# (8256, 'utmost')
# (8257, 'utter')
# (8258, 'uttered')
# (8259, 'uttering')
# (8260, 'utterly')
# (8261, 'vacancies')
# (8262, 'vacancy')
# (8263, 'vacant')
# (8264, 'vacantly')
# (8265, 'vacuous')
# (8266, 'vagabond')
# (8267, 'vagabonds')
# (8268, 'vague')
# (8269, 'vagueness')
# (8270, 'vain')
# (8271, 'vainly')
# (8272, 'valet')
# (8273, 'valid')
# (8274, 'valise')
# (8275, 'valuable')
# (8276, 'value')
# (8277, 'values')
# (8278, 'van')
# (8279, 'vanish')
# (8280, 'vanished')
# (8281, 'vanishes')
# (8282, 'vanishing')
# (8283, 'variable')
# (8284, 'varied')
# (8285, 'varieties')
# (8286, 'variety')
# (8287, 'various')
# (8288, 'vary')
# (8289, 'vault')
# (8290, 've')
# (8291, 'vegetables')
# (8292, 'vehemence')
# (8293, 'vehicle')
# (8294, 'veil')
# (8295, 'veiled')
# (8296, 'veins')
# (8297, 'velvet')
# (8298, 'vengeance')
# (8299, 'venomous')
# (8300, 'ventilate')
# (8301, 'ventilator')
# (8302, 'ventilators')
# (8303, 'venture')
# (8304, 'ventured')
# (8305, 'verbatim')
# (8306, 'verbs')
# (8307, 'verdict')
# (8308, 'verge')
# (8309, 'verify')
# (8310, 'verrons')
# (8311, 'very')
# (8312, 'vessel')
# (8313, 'vessels')
# (8314, 'vestas')
# (8315, 'vestige')
# (8316, 'vestry')
# (8317, 'vex')
# (8318, 'vice')
# (8319, 'victim')
# (8320, 'victory')
# (8321, 'view')
# (8322, 'viewed')
# (8323, 'views')
# (8324, 'vigil')
# (8325, 'vigorously')
# (8326, 'vile')
# (8327, 'vilest')
# (8328, 'villa')
# (8329, 'village')
# (8330, 'villagers')
# (8331, 'villages')
# (8332, 'villain')
# (8333, 'villains')
# (8334, 'villainy')
# (8335, 'villas')
# (8336, 'violence')
# (8337, 'violent')
# (8338, 'violet')
# (8339, 'violin')
# (8340, 'violin-land')
# (8341, 'violin-player')
# (8342, 'virtue')
# (8343, 'virtues')
# (8344, 'visible')
# (8345, 'visit')
# (8346, 'visited')
# (8347, 'visiting')
# (8348, 'visitor')
# (8349, 'visitors')
# (8350, 'visits')
# (8351, 'vital')
# (8352, 'vitriol-throwing')
# (8353, 'vivid')
# (8354, 'vizard')
# (8355, 'voice')
# (8356, 'voices')
# (8357, 'volcanic')
# (8358, 'volley')
# (8359, 'volume')
# (8360, 'volumes')
# (8361, 'volunteered')
# (8362, 'von')
# (8363, 'voraciously')
# (8364, 'vote')
# (8365, 'voters')
# (8366, 'vouching')
# (8367, 'vows')
# (8368, 'vulgar')
# (8369, 'vulnerable')
# (8370, 'wadding')
# (8371, 'waddling')
# (8372, 'wager')
# (8373, 'wages')
# (8374, 'waggled')
# (8375, 'wagon-driver')
# (8376, 'wagons')
# (8377, 'waist-high')
# (8378, 'waistcoat')
# (8379, 'wait')
# (8380, 'waited')
# (8381, 'waiter')
# (8382, 'waiting')
# (8383, 'waiting-maid')
# (8384, 'wake')
# (8385, 'walk')
# (8386, 'walked')
# (8387, 'walking')
# (8388, 'walking-clothes')
# (8389, 'walks')
# (8390, 'wall')
# (8391, 'wallowed')
# (8392, 'walls')
# (8393, 'wander')
# (8394, 'wandered')
# (8395, 'wandering')
# (8396, 'waned')
# (8397, 'want')
# (8398, 'wanted')
# (8399, 'wanting')
# (8400, 'wants')
# (8401, 'war')
# (8402, 'wardrobe')
# (8403, 'warehouse')
# (8404, 'warm')
# (8405, 'warm-hearted')
# (8406, 'warmed')
# (8407, 'warmest')
# (8408, 'warmly')
# (8409, 'warmth')
# (8410, 'warn')
# (8411, 'warned')
# (8412, 'warning')
# (8413, 'warnings')
# (8414, 'warren')
# (8415, 'was')
# (8416, 'wash')
# (8417, 'washing')
# (8418, 'wasn')
# (8419, 'waste')
# (8420, 'wasted')
# (8421, 'wasteful')
# (8422, 'watch')
# (8423, 'watch-chain')
# (8424, 'watched')
# (8425, 'watching')
# (8426, 'water')
# (8427, 'water-jug')
# (8428, 'water-mark')
# (8429, 'water-police')
# (8430, 'watered')
# (8431, 'waterproof')
# (8432, 'waters')
# (8433, 'wave')
# (8434, 'waved')
# (8435, 'wavering')
# (8436, 'waves')
# (8437, 'waving')
# (8438, 'wax')
# (8439, 'waxed')
# (8440, 'way')
# (8441, 'waylaid')
# (8442, 'ways')
# (8443, 'wayside')
# (8444, 'wayward')
# (8445, 'we')
# (8446, 'weak')
# (8447, 'weaken')
# (8448, 'weakening')
# (8449, 'weaker')
# (8450, 'weakness')
# (8451, 'weaknesses')
# (8452, 'wealth')
# (8453, 'wealthy')
# (8454, 'weapon')
# (8455, 'wear')
# (8456, 'wearer')
# (8457, 'weariness')
# (8458, 'wearing')
# (8459, 'wearisome')
# (8460, 'wears')
# (8461, 'weary')
# (8462, 'weather')
# (8463, 'weave')
# (8464, 'weaver')
# (8465, 'web')
# (8466, 'wedding')
# (8467, 'wedding-clothes')
# (8468, 'wedding-dress')
# (8469, 'wedding-morning')
# (8470, 'wedding-ring')
# (8471, 'wedged')
# (8472, 'wee')
# (8473, 'weedy')
# (8474, 'week')
# (8475, 'weekly')
# (8476, 'weeks')
# (8477, 'weigh')
# (8478, 'weighed')
# (8479, 'weighing')
# (8480, 'weight')
# (8481, 'weighted')
# (8482, 'weird')
# (8483, 'welcome')
# (8484, 'welcomed')
# (8485, 'well')
# (8486, 'well-cut')
# (8487, 'well-dressed')
# (8488, 'well-groomed')
# (8489, 'well-known')
# (8490, 'well-lit')
# (8491, 'well-nigh')
# (8492, 'well-nurtured')
# (8493, 'well-opened')
# (8494, 'well-remembered')
# (8495, 'well-to-do')
# (8496, 'went')
# (8497, 'were')
# (8498, 'west')
# (8499, 'western')
# (8500, 'westward')
# (8501, 'wet')
# (8502, 'wharf')
# (8503, 'wharves')
# (8504, 'what')
# (8505, 'whatever')
# (8506, 'wheal')
# (8507, 'wheel')
# (8508, 'wheeled')
# (8509, 'wheels')
# (8510, 'when')
# (8511, 'whence')
# (8512, 'whenever')
# (8513, 'where')
# (8514, 'whereabouts')
# (8515, 'wherever')
# (8516, 'whether')
# (8517, 'which')
# (8518, 'while')
# (8519, 'whim')
# (8520, 'whims')
# (8521, 'whimsical')
# (8522, 'whine')
# (8523, 'whined')
# (8524, 'whip')
# (8525, 'whipcord')
# (8526, 'whirling')
# (8527, 'whishing')
# (8528, 'whiskers')
# (8529, 'whisky')
# (8530, 'whisper')
# (8531, 'whispered')
# (8532, 'whispering')
# (8533, 'whistle')
# (8534, 'whistled')
# (8535, 'whistles')
# (8536, 'white')
# (8537, 'white-aproned')
# (8538, 'white-counterpaned')
# (8539, 'whiten')
# (8540, 'whiter')
# (8541, 'whitewashed')
# (8542, 'whither')
# (8543, 'who')
# (8544, 'whoa')
# (8545, 'whoever')
# (8546, 'whole')
# (8547, 'wholesome')
# (8548, 'whom')
# (8549, 'whose')
# (8550, 'whoso')
# (8551, 'why')
# (8552, 'wicked')
# (8553, 'wickedness')
# (8554, 'wicker-work')
# (8555, 'wicket')
# (8556, 'wide')
# (8557, 'widened')
# (8558, 'widespread')
# (8559, 'widow')
# (8560, 'widower')
# (8561, 'wife')
# (8562, 'wig')
# (8563, 'wigs')
# (8564, 'wild')
# (8565, 'wilderness')
# (8566, 'wilful')
# (8567, 'will')
# (8568, 'will-o')
# (8569, 'willing')
# (8570, 'willingly')
# (8571, 'win')
# (8572, 'winced')
# (8573, 'wincing')
# (8574, 'wind')
# (8575, 'wind-swept')
# (8576, 'windfall')
# (8577, 'winding')
# (8578, 'window')
# (8579, 'window-sill')
# (8580, 'windows')
# (8581, 'windowsill')
# (8582, 'winds')
# (8583, 'wine')
# (8584, 'wine-cellar')
# (8585, 'wines')
# (8586, 'wing')
# (8587, 'wings')
# (8588, 'wink')
# (8589, 'winking')
# (8590, 'winter')
# (8591, 'wintry')
# (8592, 'wire')
# (8593, 'wired')
# (8594, 'wiry')
# (8595, 'wisdom')
# (8596, 'wisely')
# (8597, 'wiser')
# (8598, 'wish')
# (8599, 'wished')
# (8600, 'wishes')
# (8601, 'wishing')
# (8602, 'wit')
# (8603, 'with')
# (8604, 'withdraw')
# (8605, 'withdrawn')
# (8606, 'within')
# (8607, 'without')
# (8608, 'witness')
# (8609, 'witnesses')
# (8610, 'wits')
# (8611, 'wives')
# (8612, 'woke')
# (8613, 'woman')
# (8614, 'womanhood')
# (8615, 'womanly')
# (8616, 'women')
# (8617, 'won')
# (8618, 'wonder')
# (8619, 'wondered')
# (8620, 'wonderful')
# (8621, 'wonderfully')
# (8622, 'wondering')
# (8623, 'wont')
# (8624, 'wood')
# (8625, 'wood-work')
# (8626, 'woodcock')
# (8627, 'wooded')
# (8628, 'wooden')
# (8629, 'wooden-legged')
# (8630, 'woods')
# (8631, 'wooing')
# (8632, 'word')
# (8633, 'words')
# (8634, 'wore')
# (8635, 'work')
# (8636, 'worked')
# (8637, 'worker')
# (8638, 'working')
# (8639, 'workmen')
# (8640, 'world')
# (8641, 'world-wide')
# (8642, 'worlds')
# (8643, 'worm-eaten')
# (8644, 'worms')
# (8645, 'worn')
# (8646, 'worry')
# (8647, 'worrying')
# (8648, 'worse')
# (8649, 'worst')
# (8650, 'worth')
# (8651, 'worthless')
# (8652, 'worthy')
# (8653, 'would')
# (8654, 'wouldn')
# (8655, 'wound')
# (8656, 'wounded')
# (8657, 'woven')
# (8658, 'wrack')
# (8659, 'wrapped')
# (8660, 'wreath')
# (8661, 'wreaths')
# (8662, 'wreck')
# (8663, 'wrenching')
# (8664, 'wretch')
# (8665, 'wretched')
# (8666, 'wriggled')
# (8667, 'wrinkled')
# (8668, 'wrinkles')
# (8669, 'wrist')
# (8670, 'wrists')
# (8671, 'writ')
# (8672, 'write')
# (8673, 'writer')
# (8674, 'writers')
# (8675, 'writes')
# (8676, 'writhed')
# (8677, 'writhing')
# (8678, 'writing')
# (8679, 'writings')
# (8680, 'written')
# (8681, 'wrong')
# (8682, 'wronged')
# (8683, 'wrongfully')
# (8684, 'wrote')
# (8685, 'wrung')
# (8686, 'yard')
# (8687, 'yards')
# (8688, 'yawn')
# (8689, 'yawning')
# (8690, 'year')
# (8691, 'years')
# (8692, 'yell')
# (8693, 'yelled')
# (8694, 'yellow')
# (8695, 'yellow-backed')
# (8696, 'yes')
# (8697, 'yesterday')
# (8698, 'yet')
# (8699, 'yonder')
# (8700, 'you')
# (8701, 'young')
# (8702, 'younger')
# (8703, 'youngster')
# (8704, 'your')
# (8705, 'yours')
# (8706, 'yourself')
# (8707, 'yourselves')
# (8708, 'youth')
# (8709, 'zero')
# (8710, 'zero-point')
# (8711, 'zest')
# (8712, 'zigzag')

# %%
vocab = {token:integer for integer,token in enumerate(all_words)}

# %% [markdown]
# - Below are the first 50 entries in this vocabulary:

# %%
for i, item in enumerate(vocab.items()):
    print(item)
    if i >= 50:
        break
# Out:
# ('A', 0)
# ('ADLER', 1)
# ('ADVENTURE', 2)
# ('ARAT', 3)
# ('Abbots', 4)
# ('Aberdeen', 5)
# ('About', 6)
# ('Above', 7)
# ('Absolute', 8)
# ('Absolutely', 9)
# ('Accustomed', 10)
# ('Across', 11)
# ('Adler', 12)
# ('Adventure', 13)
# ('Adventures', 14)
# ('Affairs', 15)
# ('Afghan', 16)
# ('Afghanistan', 17)
# ('After', 18)
# ('Again', 19)
# ('Agra', 20)
# ('Ah', 21)
# ('Air', 22)
# ('Alas', 23)
# ('Albert', 24)
# ('Aldersgate', 25)
# ('Aldershot', 26)
# ('Alexander', 27)
# ('Alice', 28)
# ('Alicia', 29)
# ('All', 30)
# ('Allegro', 31)
# ('Aloysius', 32)
# ('Alpha', 33)
# ('Already', 34)
# ('Also', 35)
# ('Altogether', 36)
# ('Always', 37)
# ('Amateur', 38)
# ('America', 39)
# ('American', 40)
# ('Americans', 41)
# ('Amid', 42)
# ('Among', 43)
# ('Amoy', 44)
# ('Ample', 45)
# ('An', 46)
# ('And', 47)
# ('Anderson', 48)
# ('Andover', 49)
# ('Angel', 50)

# %% [markdown]
# - Below, we illustrate the tokenization of a short sample text using a small vocabulary:

# %% [markdown]
# <img src="figures/05.png" width="600px">

# %% [markdown]
# - Let's now put it all together into a tokenizer class

# %%
class SimpleTokenizerV1:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i:s for s,i in vocab.items()}
    
    def encode(self, text):
        preprocessed = re.split(r'([,.?_!()\']|--|\s)', text)
        preprocessed = [
            item.strip() for item in preprocessed if item.strip()
        ]
        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.?!"()\'])', r'\1', text)
        return text

# %% [markdown]
# Note: I removed double quotes from regex

# %%
tokenizer = SimpleTokenizerV1(vocab)

# %%
tokenizer.decode([927, 71, 225, 288, 1011, 14, 5631])
# Out:
# 'Sir Arthur Conan Doyle The Adventures of'

# %% [markdown]
# - The `encode` function turns text into token IDs
# - The `decode` function turns token IDs back into text

# %% [markdown]
# <img src="figures/06.png" width="600px">

# %% [markdown]
# - We can use the tokenizer to encode (that is, tokenize) texts into integers
# - These integers can then be embedded (later) as input of/for the LLM

# %%
tokenizer = SimpleTokenizerV1(vocab)

text = """Sir Arthur Conan Doyle The Adventures of Sherlock Holmes"""
ids = tokenizer.encode(text)
print(ids)
# Out:
# [927, 71, 225, 288, 1011, 14, 5631, 913, 495]

# %% [markdown]
# Note: You might get a key error if there is no such double quotes(") in the txt or data

# %% [markdown]
# - We can decode the integers back into text

# %%
tokenizer.decode(ids)
# Out:
# 'Sir Arthur Conan Doyle The Adventures of Sherlock Holmes'

# %%
tokenizer.decode(tokenizer.encode(text))
# Out:
# 'Sir Arthur Conan Doyle The Adventures of Sherlock Holmes'

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # 2.3 BytePair encoding

# %% [markdown]
# - GPT-2 used BytePair encoding (BPE) as its tokenizer
# - it allows the model to break down words that aren't in its predefined vocabulary into smaller subword units or even individual characters, enabling it to handle out-of-vocabulary words
# - For instance, if GPT-2's vocabulary doesn't have the word "unfamiliarword," it might tokenize it as ["unfam", "iliar", "word"] or some other subword breakdown, depending on its trained BPE merges
# - The original BPE tokenizer can be found here: [https://github.com/openai/gpt-2/blob/master/src/encoder.py](https://github.com/openai/gpt-2/blob/master/src/encoder.py)
# - In this lecture, we are using the BPE tokenizer from OpenAI's open-source [tiktoken](https://github.com/openai/tiktoken) library, which implements its core algorithms in Rust to improve computational performance
# - (Based on an analysis [here](https://github.com/rasbt/LLMs-from-scratch/blob/main/ch02/02_bonus_bytepair-encoder/compare-bpe-tiktoken.ipynb), I found that `tiktoken` is approx. 3x faster than the original tokenizer and 6x faster than an equivalent tokenizer in Hugging Face)

# %%
 pip install tiktoken -q
# Out:
# [notice] A new release of pip is available: 24.1.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.7.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Sir Arthur Conan Doyle The Adventures of Sherlock Holmes. <|endoftext|> In the sunlit terraces"
     "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(integers)
# Out:
# [22788, 13514, 31634, 31233, 383, 15640, 286, 25730, 17628, 13, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
strings = tokenizer.decode(integers)

print(strings)
# Out:
# Sir Arthur Conan Doyle The Adventures of Sherlock Holmes. <|endoftext|> In the sunlit terracesof someunknownPlace.

# %% [markdown]
# - BPE tokenizers break down unknown words into subwords and individual characters:

# %% [markdown]
# <img src="figures/07.png" width="600px">

# %%
tokenizer.encode("Akwirw ier", allowed_special={"<|endoftext|>"})
# Out:
# [33901, 86, 343, 86, 220, 959]

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # 2.4 Data sampling with a sliding window

# %% [markdown]
# - Above, we took care of the tokenization (converting text into word tokens represented as token ID numbers)
# - Now, let's talk about how we create the data loading for LLMs
# - We train LLMs to generate one word at a time, so we want to prepare the training data accordingly where the next word in a sequence represents the target to predict

# %% [markdown]
# <img src="figures/08.png" width="600px">

# %% [markdown]
# - For this, we use a sliding window approach, changing the position by +1:
#
# <img src="figures/09.png" width="900px">

# %% [markdown]
# - Note that in practice it's best to set the stride equal to the context length so that we don't have overlaps between the inputs (the targets are still shifted by +1 always)

# %% [markdown]
# <img src="figures/10.png" width="600px">

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['url', 'text'],
#         num_rows: 359
#     })
# })

# %%
from supplementary import create_dataloader_v1


dataloader = create_dataloader_v1(one_book, batch_size=8, max_length=4, stride=4, shuffle=False)

data_iter = iter(dataloader)
inputs, targets = next(data_iter)
print("Inputs:\n", inputs)
print("\nTargets:\n", targets)
# Out:
# Inputs:
#  tensor([[22788, 13514, 31634, 31233],
#         [  383, 15640,   286, 25730],
#         [17628,   220,   198,   220],
#         [  198,   220,   198,   220],
#         [  220,   220,   198,   220],
#         [  220,   220,   198,   314],
#         [   13,   317,  1446,  7642],
#         [  287, 45560,   544,   220]])
#
# Targets:
#  tensor([[13514, 31634, 31233,   383],
#         [15640,   286, 25730, 17628],
#         [  220,   198,   220,   198],
#         [  220,   198,   220,   220],
#         [  220,   198,   220,   220],
#         [  220,   198,   314,    13],
#         [  317,  1446,  7642,   287],
#         [45560,   544,   220,   198]])

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Exercise: Prepare your own favorite text dataset
